# %%
import mysql.connector

class Importing:
    def __init__(self, Bus_state_name, Table_insert, table_name, database_name):
        self.Bus_state_name = Bus_state_name
        self.Table_insert = Table_insert
        self.table_name = table_name
        self.database_name = database_name

        # Connect to MySQL
        self.mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="",
            autocommit=True  # Enable autocommit
        )

        print(self.mydb)
        self.mycursor = self.mydb.cursor(buffered=True)

        # Create the database
        self.mycursor.execute(f"CREATE DATABASE IF NOT EXISTS {self.database_name}")
        self.mycursor.execute(f"USE {self.database_name}")  # Switch to the new database

        # Escape table names with backticks to handle spaces and reserved keywords
        table_name_1 = f"`{self.table_name}`"

        # Create the table with the specified schema, including Bus_route_name
        self.mycursor.execute(f"""
            CREATE TABLE IF NOT EXISTS {table_name_1} (
                id INT NOT NULL AUTO_INCREMENT,
                Bus_state_name VARCHAR(100),
                Bus_route_name VARCHAR(100),
                Bus_Operator_type VARCHAR(15),
                BusName VARCHAR(50),
                BusType VARCHAR(50),
                Departing_Time TIME,
                Duration VARCHAR(30),
                Reaching_Time TIME,
                Star_rating FLOAT(5),
                Price FLOAT(10),
                Seats_available INT(5),
                PRIMARY KEY (id)
            )
        """)

        # Insert data into the table
        for bus_route_name, operator_data in self.Table_insert.items():
            for operator_type in ['Private', 'Government']:
                print(f"Inserting data for operator type: {operator_type} on route: {bus_route_name}")
                try:
                    bus_name = operator_data[operator_type]['Bus_Name']
                    bus_type = operator_data[operator_type]['Bus_Type']
                    departing_time = operator_data[operator_type]['Departing_Time']
                    duration = operator_data[operator_type]['Duration']
                    reaching_time = operator_data[operator_type]['Reaching_Time']
                    star_rating = operator_data[operator_type]['Star_Rating']
                    price = operator_data[operator_type]['Price']
                    seats_available = operator_data[operator_type]['Seat_availability']
                except KeyError as e:
                    print(f"KeyError: {e} in route {bus_route_name} for operator type {operator_type}. Skipping...")
                    continue

                insert_query = f"INSERT INTO {table_name_1} (Bus_state_name, Bus_route_name, Bus_Operator_type, BusName, BusType, Departing_Time, Duration, Reaching_Time, Star_rating, Price, Seats_available) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s)"

                # Get the minimum length among the lists to avoid index errors
                value_lengths = [len(i) for i in [bus_name, bus_type, departing_time, duration, reaching_time, star_rating, price, seats_available]]
                min_length = min(value_lengths)
                print(f"Minimum length of lists: {min_length}")

                # Insert each value in the list as a separate row
                for i in range(min_length):
                    print(f"Inserting row {i+1} for {bus_route_name} - {operator_type}")
                    print((
                        self.Bus_state_name,
                        bus_route_name,
                        operator_type, 
                        bus_name[i], 
                        bus_type[i], 
                        departing_time[i], 
                        duration[i], 
                        reaching_time[i], 
                        star_rating[i], 
                        price[i], 
                        seats_available[i]
                    ))
                    self.mycursor.execute(insert_query, (
                        self.Bus_state_name,
                        bus_route_name,
                        operator_type, 
                        bus_name[i], 
                        bus_type[i], 
                        departing_time[i], 
                        duration[i], 
                        reaching_time[i], 
                        star_rating[i], 
                        price[i], 
                        seats_available[i]
                    ))
                    self.mydb.commit()  # Commit after each insertion

# %%
import pandas as pd

# Assuming 'TSRTC_data' is a dictionary containing the scraped data
TSRTC_data =pd.read_json("C:/Users/yuvanelson/Documents/Rebbus-Project-1-main/Rebbus-Project-1-main/TSRTC.json") # Change read_csv to read_json

#Inputing the arguments State bus name,Variable containing scraped data,Table name,Database name
importer = Importing('TSRTC-Telangana State Transport', TSRTC_data, "Bus_Data", "RedBus")
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x000001F724762840>
# Inserting data for operator type: Private on route: Khammam to Hyderabad
# Minimum length of lists: 25
# Inserting row 1 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Sri KVR Travels', 'A/C Sleeper (2+1)', '23:20', '05h 40m', '05:00', 3.2, '560', 19)
# Inserting row 2 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Sri KVR Travels', 'Non A/C Seater / Sleeper (2+1)', '23:40', '05h 20m', '05:00', 3.4, '400', 25)
# Inserting row 3 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'BSR Tours And Travels', 'NON A/C Seater (2+2)', '23:40', '06h 20m', '06:00', 4.2, '400', 31)
# Inserting row 4 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Bharathi Tours & Travels', 'Non A/C Seater / Sleeper (2+1)', '23:40', '04h 20m', '04:00', 3.8, '400', 27)
# Inserting row 5 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Sri Venkateswara Travels', 'Non A/C Seater / Sleeper (2+1)', '23:45', '06h 15m', '06:00', 3.8, '400', 28)
# Inserting row 6 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'RRR Travels', 'A/C Seater / Sleeper (2+1)', '23:50', '05h 40m', '05:30', 4.4, '450', 28)
# Inserting row 7 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Sri Krishna Travels(VGN)', 'NON A/C Hi-Tech (2+2)', '23:55', '05h 30m', '05:25', 3.7, '350', 20)
# Inserting row 8 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'SAIRAJ TRAVELS', 'A/C Seater / Sleeper (2+1)', '23:59', '05h 31m', '05:30', 5.0, '670', 18)
# Inserting row 9 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'BSR Tours And Travels', 'A/C Sleeper (2+1)', '23:59', '06h 01m', '06:00', 3.8, '800', 22)
# Inserting row 10 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Nani’s Sai Krishna Travels', 'Non A/C Seater / Sleeper (2+1)', '23:59', '05h 01m', '05:00', 4.1, '450', 32)
# Inserting row 11 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Sri Krishna Travels(VGN)', 'Non A/C Seater / Sleeper (2+1)', '23:59', '06h 11m', '06:10', 3.1, '500', 32)
# Inserting row 12 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'SAIRAJ TRAVELS', 'NON A/C Seater (2+2)', '23:59', '06h 16m', '06:15', 3.5, '500', 28)
# Inserting row 13 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Bharathi Tours & Travels', 'Non A/C Seater / Sleeper (2+1)', '23:59', '05h 01m', '05:00', 3.5, '500', 30)
# Inserting row 14 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Bharathi Tours & Travels', 'A/C Sleeper (2+1)', '23:59', '05h 01m', '05:00', 3.5, '850', 28)
# Inserting row 15 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Nani’s Sai Krishna Travels', 'Non A/C Seater / Sleeper (2+1)', '23:59', '05h 01m', '05:00', 4.1, '430', 26)
# Inserting row 16 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'BSR Tours And Travels', 'A/C Sleeper (2+1)', '23:59', '06h 01m', '06:00', 4.6, '800', 22)
# Inserting row 17 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Orange Tours And Travels', 'NON A/C Seater/ Sleeper (2+1)', '00:30', '04h 30m', '05:00', 3.7, '400', 16)
# Inserting row 18 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Sri KVR Travels', 'Non A/C Seater / Sleeper (2+1)', '00:30', '05h 00m', '05:30', 3.1, '500', 26)
# Inserting row 19 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Orange Tours And Travels', 'Bharat Benz A/C Sleeper (2+1)', '00:40', '04h 20m', '05:00', 3.0, '700', 30)
# Inserting row 20 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Mozo travels', 'A/C Seater / Sleeper (2+1)', '01:30', '04h 30m', '06:00', 4.1, '599', 22)
# Inserting row 21 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Orange Tours And Travels', 'A/C Sleeper (2+1)', '17:30', '04h 20m', '21:50', 2.5, '600', 29)
# Inserting row 22 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Morning Star Travels', 'Volvo Multi Axle B9R A/C Sleeper (2+1)', '18:00', '03h 45m', '21:45', 1.8, '790', 32)
# Inserting row 23 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Morning Star Travels', 'A/C Sleeper (2+1)', '00:45', '04h 10m', '04:55', 1.8, '650', 41)
# Inserting row 24 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'SAIRAJ TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '23:59', '06h 16m', '06:15', 4.2, '0', 33)
# Inserting row 25 for Khammam to Hyderabad - Private
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Private', 'Nani’s Sai Krishna Travels', 'NON A/C Hi-Tech Push Back (2+2)', '23:59', '05h 01m', '05:00', 4.1, '3000', 9)
# Inserting data for operator type: Government on route: Khammam to Hyderabad
# Minimum length of lists: 38
# Inserting row 1 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 64089', 'RAJDHANI (A.C. Semi Sleeper)', '18:00', '04h 00m', '22:00', 3.1, '389', 34)
# Inserting row 2 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 1952', 'LAHARI A/C SLEEPER CUM SEATER', '18:10', '03h 35m', '21:45', 3.1, '389', 35)
# Inserting row 3 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 4172', 'RAJADHANI AC (CONVERTED METRO LUXURY)', '18:30', '04h 00m', '22:30', 4.1, '389', 34)
# Inserting row 4 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 8677', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '19:30', '04h 10m', '23:40', 3.9, '320', 28)
# Inserting row 5 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 64022', 'RAJADHANI AC (CONVERTED METRO LUXURY)', '19:30', '04h 45m', '00:15', 2.8, '389', 29)
# Inserting row 6 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 8625', 'RAJDHANI (A.C. Semi Sleeper)', '21:00', '04h 00m', '01:00', 3.8, '389', 35)
# Inserting row 7 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 8619', 'RAJADHANI AC (CONVERTED METRO LUXURY)', '22:00', '04h 00m', '02:00', 3.9, '389', 29)
# Inserting row 8 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 64593', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '22:30', '03h 55m', '02:25', 4.7, '320', 26)
# Inserting row 9 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 8827', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '22:55', '04h 25m', '03:20', 4.3, '320', 33)
# Inserting row 10 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 4166', 'RAJADHANI AC (CONVERTED METRO LUXURY)', '23:00', '04h 00m', '03:00', 4.7, '389', 20)
# Inserting row 11 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 8644', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '23:10', '04h 10m', '03:20', 3.9, '320', 31)
# Inserting row 12 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 8992', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '23:25', '03h 55m', '03:20', 4.8, '320', 27)
# Inserting row 13 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 64008', 'RAJADHANI AC (CONVERTED METRO LUXURY)', '23:30', '04h 00m', '03:30', 4.0, '389', 38)
# Inserting row 14 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 8805', 'RAJDHANI (A.C. Semi Sleeper)', '23:45', '03h 45m', '03:30', 3.7, '389', 19)
# Inserting row 15 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 8600', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '23:55', '05h 25m', '05:20', 4.7, '320', 25)
# Inserting row 16 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 7646', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '23:55', '04h 35m', '04:30', 4.3, '320', 31)
# Inserting row 17 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'TSRTC - 1323', 'LAHARI A/C SLEEPER CUM SEATER', '23:55', '03h 35m', '03:30', 3.6, '389', 27)
# Inserting row 18 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Sri KVR Travels', 'A/C Sleeper (2+1)', '23:20', '05h 40m', '05:00', 3.2, '560', 28)
# Inserting row 19 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Sri KVR Travels', 'Non A/C Seater / Sleeper (2+1)', '23:40', '05h 20m', '05:00', 3.4, '400', 28)
# Inserting row 20 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'BSR Tours And Travels', 'NON A/C Seater (2+2)', '23:40', '06h 20m', '06:00', 4.2, '400', 20)
# Inserting row 21 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Bharathi Tours & Travels', 'Non A/C Seater / Sleeper (2+1)', '23:40', '04h 20m', '04:00', 3.8, '400', 18)
# Inserting row 22 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Sri Venkateswara Travels', 'Non A/C Seater / Sleeper (2+1)', '23:45', '06h 15m', '06:00', 3.8, '400', 22)
# Inserting row 23 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'RRR Travels', 'A/C Seater / Sleeper (2+1)', '23:50', '05h 40m', '05:30', 4.4, '450', 32)
# Inserting row 24 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Sri Krishna Travels(VGN)', 'NON A/C Hi-Tech (2+2)', '23:55', '05h 30m', '05:25', 3.7, '350', 32)
# Inserting row 25 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'SAIRAJ TRAVELS', 'A/C Seater / Sleeper (2+1)', '23:59', '05h 31m', '05:30', 5.0, '670', 28)
# Inserting row 26 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'BSR Tours And Travels', 'A/C Sleeper (2+1)', '23:59', '06h 01m', '06:00', 3.8, '800', 30)
# Inserting row 27 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Nani’s Sai Krishna Travels', 'Non A/C Seater / Sleeper (2+1)', '23:59', '05h 01m', '05:00', 4.1, '450', 28)
# Inserting row 28 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Sri Krishna Travels(VGN)', 'Non A/C Seater / Sleeper (2+1)', '23:59', '06h 11m', '06:10', 3.1, '500', 26)
# Inserting row 29 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'SAIRAJ TRAVELS', 'NON A/C Seater (2+2)', '23:59', '06h 16m', '06:15', 3.5, '500', 22)
# Inserting row 30 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Bharathi Tours & Travels', 'Non A/C Seater / Sleeper (2+1)', '23:59', '05h 01m', '05:00', 3.5, '500', 16)
# Inserting row 31 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Bharathi Tours & Travels', 'A/C Sleeper (2+1)', '23:59', '05h 01m', '05:00', 3.5, '850', 26)
# Inserting row 32 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Nani’s Sai Krishna Travels', 'Non A/C Seater / Sleeper (2+1)', '23:59', '05h 01m', '05:00', 4.1, '430', 30)
# Inserting row 33 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'BSR Tours And Travels', 'A/C Sleeper (2+1)', '23:59', '06h 01m', '06:00', 4.6, '800', 22)
# Inserting row 34 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Orange Tours And Travels', 'NON A/C Seater/ Sleeper (2+1)', '00:30', '04h 30m', '05:00', 3.7, '400', 29)
# Inserting row 35 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Sri KVR Travels', 'Non A/C Seater / Sleeper (2+1)', '00:30', '05h 00m', '05:30', 3.1, '500', 32)
# Inserting row 36 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Orange Tours And Travels', 'Bharat Benz A/C Sleeper (2+1)', '00:40', '04h 20m', '05:00', 3.0, '700', 41)
# Inserting row 37 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Mozo travels', 'A/C Seater / Sleeper (2+1)', '01:30', '04h 30m', '06:00', 4.1, '599', 33)
# Inserting row 38 for Khammam to Hyderabad - Government
# ('TSRTC-Telangana State Transport', 'Khammam to Hyderabad', 'Government', 'Orange Tours And Travels', 'A/C Sleeper (2+1)', '17:30', '04h 20m', '21:50', 2.5, '600', 9)
# Inserting data for operator type: Private on route: Hyderabad to Vijayawada
# Minimum length of lists: 243
# Inserting row 1 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:20', '07h 15m', '05:35', 4.6, '926', 13)
# Inserting row 2 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'Scania AC Multi Axle Sleeper (2+1)', '23:00', '07h 30m', '06:30', 4.6, '668', 13)
# Inserting row 3 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '22:25', '07h 35m', '06:00', 4.5, '624', 22)
# Inserting row 4 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'AdSri Sanvi Tours and Travels', 'A/C Sleeper (2+1)', '22:20', '06h 33m', '04:53', 4.5, '539', 6)
# Inserting row 5 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '22:45', '06h 50m', '05:35', 4.4, '605', 17)
# Inserting row 6 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '23:40', '06h 50m', '06:30', 4.5, '680', 17)
# Inserting row 7 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'GMRK Tours and Travels', 'Volvo A/C Semi Sleeper (2+2)', '22:30', '06h 55m', '05:25', 4.5, '890', 17)
# Inserting row 8 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'AdIntrCity SmartBus', 'Bharat Benz A/C Seater /Sleeper (2+1)', '21:55', '07h 25m', '05:20', 4.3, '790', 15)
# Inserting row 9 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:05', '07h 15m', '05:20', 4.4, '799', 13)
# Inserting row 10 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Svkdt travels', 'A/C Seater / Sleeper (2+1)', '22:20', '07h 10m', '05:30', 4.4, '710', 22)
# Inserting row 11 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '22:05', '07h 55m', '06:00', 4.4, '699', 13)
# Inserting row 12 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri KVR Travels', 'A/C Sleeper (2+1)', '21:45', '07h 30m', '05:15', 4.4, '680', 14)
# Inserting row 13 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Zingbus Plus', 'A/C Seater / Sleeper (2+1)', '22:50', '07h 20m', '06:10', 4.4, '490', 23)
# Inserting row 14 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Svkdt travels', 'A/C Sleeper (2+1)', '22:20', '07h 30m', '05:50', 4.2, '744', 11)
# Inserting row 15 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater/Sleeper (2+1)', '22:25', '07h 35m', '06:00', 4.1, '1600', 12)
# Inserting row 16 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '22:45', '07h 50m', '06:35', 4.4, '780', 11)
# Inserting row 17 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Tirumala Xpress', 'A/C Sleeper (2+1)', '21:35', '08h 15m', '05:50', 4.1, '1280', 22)
# Inserting row 18 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri KVR Travels', 'NON A/C Sleeper (2+1)', '21:05', '08h 26m', '05:31', 4.3, '3', 17)
# Inserting row 19 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '21:55', '07h 40m', '05:35', 4.0, '890', 11)
# Inserting row 20 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'LVP Travels', 'A/C Seater / Sleeper (2+1)', '21:00', '07h 45m', '04:45', 4.1, '780', 22)
# Inserting row 21 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '23:15', '06h 40m', '05:55', 4.2, '1399', 18)
# Inserting row 22 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Venkata Padmavathi Travels', 'Non A/C Seater / Sleeper (2+1)', '21:40', '08h 20m', '06:00', 4.4, '980', 22)
# Inserting row 23 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sitara Travels', 'NON A/C Push Back (2+2)', '22:00', '06h 00m', '04:00', 4.4, '950', 12)
# Inserting row 24 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Keerthana Sai Travels', 'A/C Sleeper (2+1)', '17:40', '06h 05m', '23:45', 4.5, '1090', 16)
# Inserting row 25 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sai Srinivasa Travels', 'A/C Sleeper (2+1)', '21:30', '06h 45m', '04:15', 4.1, '1799', 12)
# Inserting row 26 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'BSR Tours And Travels', 'A/C Sleeper (2+1)', '20:50', '07h 10m', '04:00', 4.0, '890', 15)
# Inserting row 27 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Zingbus Plus', 'A/C Sleeper (2+1)', '17:40', '07h 10m', '00:50', 4.4, '1110', 27)
# Inserting row 28 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Navayuga Travels', 'NON AC Seater / Sleeper 2+1', '21:10', '07h 00m', '04:10', 4.2, '1359', 12)
# Inserting row 29 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Mayuri Travels', 'Non A/C Seater / Sleeper (2+1)', '20:40', '07h 20m', '04:00', 4.0, '780', 12)
# Inserting row 30 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Mythri Tours And Travels', 'A/C Sleeper (2+1)', '21:15', '06h 50m', '04:05', 4.3, '780', 15)
# Inserting row 31 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'BSR Tours And Travels', 'A/C Seater / Sleeper (2+1)', '18:00', '08h 30m', '02:30', 4.0, '1550', 28)
# Inserting row 32 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Keerthana Sai Travels', 'Non A/C Seater / Sleeper (2+1)', '17:40', '06h 05m', '23:45', 4.5, '869', 11)
# Inserting row 33 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'GMC Travels', 'A/C Seater / Sleeper (2+1)', '21:00', '06h 30m', '03:30', 4.5, '600', 32)
# Inserting row 34 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Svkdt travels', 'A/C Sleeper (2+1)', '17:29', '08h 46m', '02:05', 4.4, '890', 27)
# Inserting row 35 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Navayuga Travels', 'NON AC Seater / Sleeper 2+1', '19:50', '08h 40m', '04:30', 4.3, '815', 15)
# Inserting row 36 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Navayuga Travels', 'A/C Seater / Sleeper (2+1)', '21:45', '06h 45m', '04:30', 4.3, '894', 12)
# Inserting row 37 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Vikram Travels', 'A/C Sleeper (2+1)', '19:20', '06h 40m', '02:00', 4.1, '9', 18)
# Inserting row 38 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Jayanthi Travels', 'Non A/C Seater / Sleeper (2+1)', '20:15', '06h 45m', '03:00', 4.1, '1041', 13)
# Inserting row 39 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Jayanthi Travels', 'NON A/C Hi-Tech Push Back (2+2)', '21:00', '07h 15m', '04:15', 4.1, '520', 16)
# Inserting row 40 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Jayanthi Travels', 'A/C Sleeper (2+1)', '20:15', '07h 15m', '03:30', 4.1, '660', 23)
# Inserting row 41 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Vikram Travels', 'A/C Seater / Sleeper (2+1)', '20:30', '07h 30m', '04:00', 4.1, '890', 2)
# Inserting row 42 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Bharathi Tours & Travels', 'Non A/C Seater / Sleeper (2+1)', '21:20', '08h 10m', '05:30', 4.0, '1299', 8)
# Inserting row 43 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Svkdt travels', 'A/C Sleeper (2+1)', '22:20', '07h 30m', '05:50', 4.6, '1280', 6)
# Inserting row 44 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '22:25', '07h 40m', '06:05', 4.5, '1480', 9)
# Inserting row 45 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater/Sleeper (2+1)', '21:25', '07h 45m', '05:10', 4.6, '610', 9)
# Inserting row 46 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '22:10', '07h 55m', '06:05', 4.4, '670', 10)
# Inserting row 47 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '23:00', '06h 55m', '05:55', 4.4, '1100', 5)
# Inserting row 48 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '22:10', '07h 05m', '05:15', 4.5, '1493', 3)
# Inserting row 49 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '20:55', '07h 25m', '04:20', 4.3, '1361', 10)
# Inserting row 50 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Durga Malleswari Travels', 'A/C Sleeper (2+1)', '21:50', '07h 35m', '05:25', 4.4, '1662', 7)
# Inserting row 51 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '17:40', '05h 20m', '23:00', 4.3, '1439', 10)
# Inserting row 52 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '22:45', '08h 00m', '06:45', 4.4, '1199', 10)
# Inserting row 53 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '23:25', '07h 05m', '06:30', 4.2, '888', 8)
# Inserting row 54 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Yolo Bus', 'A/C Seater / Sleeper (2+1)', '22:15', '07h 09m', '05:24', 4.1, '1800', 8)
# Inserting row 55 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri KVR Travels', 'Non A/C Seater / Sleeper (2+1)', '21:08', '07h 12m', '04:20', 4.0, '1200', 9)
# Inserting row 56 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Go Tour Travels and Holidays', 'A/C Seater / Sleeper (2+1)', '21:45', '06h 30m', '04:15', 4.5, '1510', 5)
# Inserting row 57 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Zingbus Plus', 'A/C Sleeper (2+1)', '17:40', '06h 05m', '23:45', 4.7, '790', 6)
# Inserting row 58 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Mythri Tours And Travels', 'A/C Sleeper (2+1)', '19:10', '07h 18m', '02:28', 4.7, '1199', 10)
# Inserting row 59 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'BSR Tours And Travels', 'VE A/C Sleeper (2+1)', '20:50', '07h 20m', '04:10', 4.3, '890', 7)
# Inserting row 60 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '21:30', '05h 30m', '03:00', 4.9, '777', 6)
# Inserting row 61 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'GO BUS', 'Non A/C Seater / Sleeper (2+1)', '21:45', '07h 05m', '04:50', 4.0, '777', 9)
# Inserting row 62 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Atluri Travels', 'NON A/C Hi-Tech (2+2)', '21:20', '07h 00m', '04:20', 4.1, '750', 2)
# Inserting row 63 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Pavan Tours and Travels', 'A/C Sleeper (2+1)', '22:30', '06h 25m', '04:55', 4.5, '2999', 4)
# Inserting row 64 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Atluri Travels', 'A/C Seater / Sleeper (2+1)', '21:20', '07h 47m', '05:07', 4.0, '1099', 3)
# Inserting row 65 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'V Kaveri Travels', 'A/C Sleeper (2+1)', '21:30', '07h 00m', '04:30', 4.8, '650', 4)
# Inserting row 66 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '18:00', '06h 20m', '00:20', 4.5, '890', 7)
# Inserting row 67 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'VE A/C Seater / Sleeper (2+1)', '20:45', '05h 25m', '02:10', 4.1, '1190', 9)
# Inserting row 68 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '18:05', '07h 05m', '01:10', 5.0, '870', 3)
# Inserting row 69 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Tirumala Travels', 'A/C Sleeper (2+1)', '20:30', '08h 00m', '04:30', 4.4, '800', 10)
# Inserting row 70 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'SAMANVI CITICONNECT', 'A/C Sleeper (2+1)', '20:40', '07h 40m', '04:20', 4.0, '700', 6)
# Inserting row 71 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Rama Travels', 'Non A/C Seater / Sleeper (2+1)', '21:45', '06h 30m', '04:15', 4.3, '900', 3)
# Inserting row 72 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Orange Tours And Travels', 'Volvo 9600 Multi-Axle A/C Sleeper (2+1)', '21:10', '07h 40m', '04:50', 4.0, '670', 5)
# Inserting row 73 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Neelachal Travels', 'A/C Seater / Sleeper (2+1)', '17:40', '05h 05m', '22:45', 4.5, '690', 2)
# Inserting row 74 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sree Gowtham Travels', 'A/C Sleeper (2+1)', '21:45', '07h 47m', '05:32', 4.2, '599', 8)
# Inserting row 75 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Vikram Travels', 'A/C Sleeper (2+1)', '20:30', '06h 30m', '03:00', 4.1, '700', 9)
# Inserting row 76 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri KVR Travels', 'Non A/C Seater / Sleeper (2+1)', '18:00', '08h 25m', '02:25', 4.1, '880', 4)
# Inserting row 77 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri KVR Travels', 'A/C Seater / Sleeper (2+1)', '17:55', '06h 45m', '00:40', 4.1, '999', 7)
# Inserting row 78 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Padma Travels', 'Non A/C Seater / Sleeper (2+1)', '21:15', '06h 45m', '04:00', 4.0, '780', 16)
# Inserting row 79 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Atluri Travels', 'NON AC Seater / Sleeper 2+1', '20:00', '08h 20m', '04:20', 4.0, '872', 12)
# Inserting row 80 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Atluri Travels', 'Non A/C Seater / Sleeper (2+1)', '20:00', '07h 50m', '03:50', 4.0, '1440', 11)
# Inserting row 81 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '17:40', '05h 00m', '22:40', 4.9, '1399', 18)
# Inserting row 82 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sai Srinivasa Travels', 'Non A/C Seater / Sleeper (2+1)', '21:30', '06h 35m', '04:05', 4.1, '999', 15)
# Inserting row 83 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Shyamoli Paribahan Pvt Ltd', 'A/C Seater/Sleeper (2+1)', '20:00', '06h 30m', '02:30', 4.3, '780', 11)
# Inserting row 84 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Shree Manikanta Travels', 'A/C Sleeper (2+1)', '18:00', '05h 40m', '23:40', 4.0, '900', 13)
# Inserting row 85 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '22:55', '07h 35m', '06:30', 3.9, '900', 16)
# Inserting row 86 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Durga Malleswari Travels', 'A/C Sleeper (2+1)', '21:45', '06h 50m', '04:35', 3.9, '890', 12)
# Inserting row 87 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'V Kaveri Travels', 'A/C Seater / Sleeper (2+1)', '21:40', '06h 35m', '04:15', 3.8, '1000', 14)
# Inserting row 88 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Morning Star Travels', 'A/C Sleeper (2+1)', '22:15', '07h 05m', '05:20', 3.2, '550', 20)
# Inserting row 89 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Kaveri Travels', 'A/C Volvo B11R Multi-Axle Sleeper (2+1)', '20:50', '07h 15m', '04:05', 3.8, '3', 15)
# Inserting row 90 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Nani Svkdt Travels', 'A/C Sleeper (2+1)', '22:00', '06h 30m', '04:30', 3.4, '777', 11)
# Inserting row 91 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Durga Malleswari Travels', 'A/C Seater / Sleeper (2+1)', '21:00', '07h 40m', '04:40', 3.5, '800', 14)
# Inserting row 92 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'V Kaveri Travels', 'Non A/C Seater / Sleeper (2+1)', '21:00', '07h 30m', '04:30', 3.5, '780', 22)
# Inserting row 93 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Orange Tours And Travels', 'NON A/C Seater/ Sleeper (2+1)', '22:00', '07h 00m', '05:00', 3.1, '799', 18)
# Inserting row 94 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Orange Tours And Travels', 'A/C Sleeper (2+1)', '22:00', '06h 45m', '04:45', 3.0, '780', 13)
# Inserting row 95 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sai RK Travels', 'Non A/C Seater / Sleeper (2+1)', '21:50', '06h 45m', '04:35', 3.7, '880', 11)
# Inserting row 96 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sudha Sri Tours and Travels', 'A/C Sleeper (2+1)', '22:10', '05h 50m', '04:00', 3.4, '990', 14)
# Inserting row 97 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Eswar Travels', 'A/C Seater / Sleeper (2+1)', '21:15', '07h 15m', '04:30', 3.2, '780', 11)
# Inserting row 98 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'V Kaveri Travels', 'Non A/C Seater / Sleeper (2+1)', '21:00', '07h 30m', '04:30', 3.9, '1499', 11)
# Inserting row 99 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'LVP Travels', 'A/C Seater / Sleeper (2+1)', '21:00', '07h 20m', '04:20', 3.6, '1999', 20)
# Inserting row 100 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Royal Varma Travels', 'A/C Sleeper (2+1)', '21:55', '06h 50m', '04:45', 3.5, '780', 14)
# Inserting row 101 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sai RK Travels', 'Non A/C Seater / Sleeper (2+1)', '22:00', '06h 10m', '04:10', 3.5, '550', 19)
# Inserting row 102 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Venkata Padmavathi Travels', 'A/C Seater / Sleeper (2+1)', '21:35', '07h 10m', '04:45', 3.3, '1999', 26)
# Inserting row 103 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Kaveri Travels', 'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)', '20:50', '07h 45m', '04:35', 3.2, '3800', 27)
# Inserting row 104 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Komali Travels', 'Non A/C Seater / Sleeper (2+1)', '21:00', '07h 30m', '04:30', 3.4, '1220', 33)
# Inserting row 105 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Srivastav Travels', 'A/C Sleeper (2+1)', '20:40', '08h 10m', '04:50', 3.3, '780', 19)
# Inserting row 106 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Rama Travels', 'A/C Seater / Sleeper (2+1)', '21:40', '06h 35m', '04:15', 3.9, '780', 13)
# Inserting row 107 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'LVP Travels', 'A/C Seater / Sleeper (2+1)', '21:00', '07h 10m', '04:10', 3.6, '780', 23)
# Inserting row 108 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Varun Travels', 'Scania AC Multi Axle Sleeper (2+1)', '22:45', '06h 00m', '04:45', 3.7, '660', 18)
# Inserting row 109 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Mayuri Travels', 'A/C Seater / Sleeper (2+1)', '17:40', '06h 15m', '23:55', 3.3, '1400', 25)
# Inserting row 110 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Apple Travels', 'A/C Seater / Sleeper (2+1)', '21:40', '05h 50m', '03:30', 3.0, '960', 15)
# Inserting row 111 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Kaveri Travels', 'Non A/C Seater / Sleeper (2+1)', '20:50', '07h 40m', '04:30', 3.1, '799', 16)
# Inserting row 112 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Prasanna Travels', 'A/C Seater / Sleeper (2+1)', '23:10', '07h 05m', '06:15', 3.3, '889', 36)
# Inserting row 113 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sai Virat Travels', 'Volvo Multi-Axle A/C Sleeper (2+1)', '21:15', '06h 10m', '03:25', 3.9, '780', 20)
# Inserting row 114 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Laharisa Tours and Travels', 'Non A/C Seater / Sleeper (2+1)', '20:15', '07h 50m', '04:05', 3.9, '890', 22)
# Inserting row 115 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Orange Tours And Travels', 'Volvo Multi-Axle Sleeper A/C (2+1)', '22:00', '06h 45m', '04:45', 3.0, '700', 22)
# Inserting row 116 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Vahini Travels', 'Non A/C Seater / Sleeper (2+1)', '21:10', '07h 35m', '04:45', 3.7, '670', 14)
# Inserting row 117 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'AMIGOS TRAVELS', 'A/C Sleeper (2+1)', '22:10', '06h 40m', '04:50', 3.7, '660', 28)
# Inserting row 118 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Vahini Travels', 'Non A/C Seater / Sleeper (2+1)', '19:35', '08h 55m', '04:30', 3.7, '750', 23)
# Inserting row 119 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'DMR Travels', 'Non A/C Seater / Sleeper (2+1)', '21:35', '06h 55m', '04:30', 3.6, '1380', 24)
# Inserting row 120 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'DMR Travels', 'Non A/C Seater / Sleeper (2+1)', '21:35', '06h 55m', '04:30', 3.6, '1449', 21)
# Inserting row 121 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'DMR Travels', 'Non A/C Seater / Sleeper (2+1)', '21:30', '07h 00m', '04:30', 3.6, '1199', 15)
# Inserting row 122 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'DMR Travels', 'A/C Sleeper (2+1)', '20:40', '06h 50m', '03:30', 3.6, '1499', 19)
# Inserting row 123 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'DMR Travels', 'A/C Sleeper (2+1)', '20:40', '07h 00m', '03:40', 3.6, '0', 20)
# Inserting row 124 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'DMR Travels', 'Non A/C Seater / Sleeper (2+1)', '21:50', '06h 10m', '04:00', 3.6, '799', 13)
# Inserting row 125 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Prasanna Travels', 'A/C Seater / Sleeper (2+1)', '22:05', '07h 30m', '05:35', 3.1, '1349', 24)
# Inserting row 126 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Mayuri Travels', 'A/C Sleeper (2+1)', '19:10', '07h 20m', '02:30', 3.4, '780', 24)
# Inserting row 127 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'R National Travels', 'A/C Sleeper (2+1)', '20:30', '08h 30m', '05:00', 3.4, '3000', 14)
# Inserting row 128 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Mayuri Travels', 'A/C Seater / Sleeper (2+1)', '17:40', '06h 15m', '23:55', 3.4, '599', 13)
# Inserting row 129 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'CVR Travels', 'Non A/C Seater / Sleeper (2+1)', '21:30', '06h 47m', '04:17', 3.4, '599', 28)
# Inserting row 130 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Mayuri Travels', 'Non A/C Seater / Sleeper (2+1)', '19:10', '06h 50m', '02:00', 3.4, '900', 12)
# Inserting row 131 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Komali Travels', 'A/C Seater / Sleeper (2+1)', '21:00', '07h 00m', '04:00', 3.4, '700', 27)
# Inserting row 132 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sai Godavari Travels', 'Non A/C Seater / Sleeper (2+1)', '21:00', '07h 00m', '04:00', 3.3, '600', 14)
# Inserting row 133 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Ajay Bus', 'Non A/C Seater / Sleeper (2+1)', '22:00', '06h 30m', '04:30', 3.2, '800', 14)
# Inserting row 134 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'KVR Tours and Travels', 'A/C Sleeper (2+1)', '19:00', '07h 05m', '02:05', 3.1, '800', 30)
# Inserting row 135 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Rainbow Tours And Travels', 'A/C Seater/Sleeper (2+1)', '19:45', '07h 45m', '03:30', 3.0, '500', 33)
# Inserting row 136 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Meghana Travels', 'Non A/C Seater / Sleeper (2+1)', '21:50', '06h 35m', '04:25', 3.0, '700', 14)
# Inserting row 137 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Srivastav Travels', 'Non A/C Seater / Sleeper (2+1)', '20:40', '07h 20m', '04:00', 3.0, '400', 25)
# Inserting row 138 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Rainbow Tours And Travels', 'Non A/C Seater / Sleeper (2+1)', '20:50', '07h 25m', '04:15', 3.0, '1110', 25)
# Inserting row 139 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Rainbow Tours And Travels', 'Non A/C Seater / Sleeper (2+1)', '20:50', '07h 45m', '04:35', 3.0, '790', 22)
# Inserting row 140 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'YNR Travels', 'A/C Sleeper (2+1)', '23:40', '06h 30m', '06:10', 3.7, '800', 26)
# Inserting row 141 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sri Krishna Travels', 'A/C Sleeper (2+1)', '21:20', '07h 50m', '05:10', 3.3, '780', 32)
# Inserting row 142 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'CVR Express', 'Non A/C Seater / Sleeper (2+1)', '20:40', '07h 45m', '04:25', 3.0, '1100', 16)
# Inserting row 143 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Ajay Bus', 'Non A/C Seater / Sleeper (2+1)', '22:00', '06h 40m', '04:40', 3.2, '880', 11)
# Inserting row 144 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Sai Dasari Travels', 'Non A/C Seater / Sleeper (2+1)', '21:55', '06h 32m', '04:27', 3.3, '710', 12)
# Inserting row 145 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'V Kaveri Travels', 'A/C Sleeper (2+1)', '21:00', '07h 45m', '04:45', 3.4, '1220', 31)
# Inserting row 146 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'Tranzindia Travels', 'Volvo Multi-Axle A/C Sleeper (2+1)', '20:40', '07h 10m', '03:50', 3.0, '890', 33)
# Inserting row 147 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'SLGT Travels', 'A/C Seater/Sleeper (2+1)', '21:30', '07h 00m', '04:30', 3.1, '1222', 9)
# Inserting row 148 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'SANDHYA TRAVELS', 'Bharat Benz A/C Sleeper (2+1)', '22:30', '06h 40m', '05:10', 3.9, '990', 8)
# Inserting row 149 for Hyderabad to Vijayawada - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Vijayawada', 'Private', 'SANDHYA TRAVELS', 'Bharat Benz A/C Sleeper (2+1)', '22:35', '06h 40m', '05:15', 3.9, '890', 6)
# Inserting row 150 for Hyderabad to Vijayawada - Private
# ...
# Inserting row 37 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'V Kaveri Travels', 'VE A/C Sleeper (2+1)', '18:15', '13h 15m', '07:30', 3.8, '899', 8)
# Inserting row 38 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Jagan Travels', 'A/C Sleeper (2+1)', '22:05', '11h 40m', '09:45', 3.8, '9', 6)
# Inserting row 39 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Orange Tours And Travels', 'A/C Sleeper (2+1)', '18:15', '11h 30m', '05:45', 3.1, '999', 5)
# Inserting row 40 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Balaji Cabs', 'Bharat Benz A/C Sleeper (2+1)', '18:30', '09h 00m', '03:30', 3.8, '5', 2)
# Inserting row 41 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Zingbus Plus', 'A/C Sleeper (2+1)', '21:00', '11h 20m', '08:20', 3.9, '2499', 8)
# Inserting row 42 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Vandana Travels', 'NON A/C Sleeper (2+1)', '21:15', '11h 45m', '09:00', 3.4, '4999', 5)
# Inserting row 43 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Mozo travels', 'A/C Sleeper (2+1)', '18:05', '12h 55m', '07:00', 3.5, '1050', 6)
# Inserting row 44 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Balaji Cabs', 'Bharat Benz A/C Sleeper (2+1)', '18:15', '07h 45m', '02:00', 3.8, '2', 8)
# Inserting row 45 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'True Bus', 'Volvo Multi Axle B9R A/C Sleeper (2+1)', '18:10', '10h 50m', '05:00', 3.9, '999', 1)
# Inserting row 46 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'VEGA BUS', 'A/C Seater / Sleeper (2+1)', '22:15', '11h 30m', '09:45', 3.1, '950', 1)
# Inserting row 47 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Mahi Trans Solutions', 'A/C Sleeper (2+1)', '18:50', '12h 25m', '07:15', 3.7, '1100', 1)
# Inserting row 48 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Mahi Trans Solutions', 'A/C Sleeper (2+1)', '18:45', '12h 30m', '07:15', 3.7, '2', 1)
# Inserting row 49 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Meghana Travels', 'A/C Sleeper (2+1)', '21:50', '11h 10m', '09:00', 2.3, '1000', 13)
# Inserting row 50 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'PMR Express', 'A/C Sleeper (2+1)', '19:00', '12h 30m', '07:30', 2.6, '1090', 22)
# Inserting row 51 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'DHANUNJAYA TRAVELS', 'A/C Sleeper (2+1)', '20:00', '12h 35m', '08:35', 1.6, '990', 14)
# Inserting row 52 for Hyderabad to Tirupati - Private
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Private', 'Vandana Travels', 'A/C Seater / Sleeper (2+1)', '21:10', '11h 50m', '09:00', 2.3, '1100', 16)
# Inserting data for operator type: Government on route: Hyderabad to Tirupati
# Minimum length of lists: 56
# Inserting row 1 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'TSRTC - 8454', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '19:45', '12h 15m', '08:00', 2.3, '780', 9)
# Inserting row 2 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'TSRTC - 6206', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '19:45', '11h 05m', '06:50', 2.9, '732', 5)
# Inserting row 3 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'TSRTC - 1498', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '20:00', '12h 30m', '08:30', 4.3, '732', 17)
# Inserting row 4 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'TSRTC - 2469', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:00', '12h 30m', '09:30', 2.8, '764', 7)
# Inserting row 5 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Jagan Travels', 'A/C Seater / Sleeper (2+1)', '22:00', '11h 30m', '09:30', 4.6, '700', 11)
# Inserting row 6 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Zingbus Plus', 'A/C Sleeper (2+1)', '18:30', '13h 25m', '07:55', 4.3, '4000', 17)
# Inserting row 7 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Anagha Travels', 'A/C Seater / Sleeper (2+1)', '18:10', '11h 35m', '05:45', 4.2, '0', 25)
# Inserting row 8 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'True Bus', 'Volvo Multi Axle B9R A/C Sleeper (2+1)', '22:30', '10h 30m', '09:00', 4.7, '1566', 36)
# Inserting row 9 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Ramana Tours And Travels', 'A/C Sleeper (2+1)', '19:55', '12h 40m', '08:35', 4.7, '1029', 1)
# Inserting row 10 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '18:35', '12h 45m', '07:20', 4.7, '1080', 1)
# Inserting row 11 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Vikram Travels', 'A/C Sleeper (2+1)', '20:20', '12h 10m', '08:30', 4.6, '400', 9)
# Inserting row 12 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '18:05', '12h 40m', '06:45', 4.4, '900', 3)
# Inserting row 13 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Yolo Bus', 'Bharat Benz A/C Seater /Sleeper (2+1)', '18:20', '10h 29m', '04:49', 4.3, '800', 2)
# Inserting row 14 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Jagan Travels', 'Scania AC Multi Axle Sleeper (2+1)', '19:20', '11h 55m', '07:15', 4.3, '1090', 7)
# Inserting row 15 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Moksha Travels', 'A/C Sleeper (2+1)', '18:05', '11h 40m', '05:45', 4.4, '500', 6)
# Inserting row 16 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Moksha Travels', 'A/C Sleeper (2+1)', '19:05', '11h 55m', '07:00', 4.2, '900', 5)
# Inserting row 17 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Sai Karthik Travels', 'Non A/C Seater / Sleeper (2+1)', '21:40', '11h 35m', '09:15', 4.4, '800', 7)
# Inserting row 18 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'CMR Express', 'Non A/C Seater / Sleeper (2+1)', '21:10', '11h 35m', '08:45', 4.2, '1399', 4)
# Inserting row 19 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Yolo Bus', 'Bharat Benz A/C Seater /Sleeper (2+1)', '18:30', '11h 39m', '06:09', 4.3, '1400', 8)
# Inserting row 20 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Jagan Travels', 'Non A/C Seater / Sleeper (2+1)', '21:30', '12h 20m', '09:50', 4.3, '1147', 9)
# Inserting row 21 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'CGR Travels', 'A/C Seater / Sleeper (2+1)', '21:50', '11h 25m', '09:15', 4.0, '0', 6)
# Inserting row 22 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Go Tour Travels and Holidays', 'A/C Sleeper (2+1)', '20:50', '12h 40m', '09:30', 4.5, '0', 4)
# Inserting row 23 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'CMR Express', 'A/C Sleeper (2+1)', '21:10', '11h 40m', '08:50', 4.1, '900', 7)
# Inserting row 24 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '20:00', '11h 50m', '07:50', 4.6, '900', 7)
# Inserting row 25 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Nanthi Travels', 'A/C Sleeper (2+1)', '18:10', '09h 05m', '03:15', 4.2, '850', 6)
# Inserting row 26 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Anagha Travels', 'A/C Sleeper (2+1)', '22:00', '11h 15m', '09:15', 3.9, '1000', 15)
# Inserting row 27 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Vandana Travels', 'A/C Seater / Sleeper (2+1)', '22:10', '10h 50m', '09:00', 3.8, '1200', 18)
# Inserting row 28 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Mozo travels', 'A/C Seater / Sleeper (2+1)', '18:05', '15h 15m', '09:20', 3.6, '1200', 21)
# Inserting row 29 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Anagha Travels', 'Non A/C Seater / Sleeper (2+1)', '22:00', '10h 55m', '08:55', 3.6, '9', 11)
# Inserting row 30 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Vandana Travels', 'A/C Seater / Sleeper (2+1)', '21:10', '11h 50m', '09:00', 3.9, '900', 17)
# Inserting row 31 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Orange Tours And Travels', 'A/C Sleeper (2+1)', '19:00', '12h 00m', '07:00', 3.0, '4', 12)
# Inserting row 32 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Sri Krishna Travels', 'A/C Sleeper (2+1)', '20:10', '12h 20m', '08:30', 3.0, '4', 16)
# Inserting row 33 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'SREE LEKYAA TRAVELS', 'A/C Sleeper (2+1)', '21:50', '11h 25m', '09:15', 3.2, '5000', 22)
# Inserting row 34 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'SRI RATAN TATA EXPRESS', 'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)', '23:40', '10h 00m', '09:40', 3.8, '1000', 22)
# Inserting row 35 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'V Kaveri Travels', 'Non A/C Seater / Sleeper (2+1)', '21:00', '11h 30m', '08:30', 3.4, '1000', 15)
# Inserting row 36 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'PMR Express', 'A/C Sleeper (2+1)', '19:00', '12h 30m', '07:30', 3.8, '1150', 26)
# Inserting row 37 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'SRI RATAN TATA EXPRESS', 'A/C Sleeper (2+1)', '23:59', '10h 01m', '10:00', 3.8, '1060', 21)
# Inserting row 38 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'RK Travels', 'Non A/C Seater / Sleeper (2+1)', '21:00', '0-12h 0-30m', '09:30', 3.6, '1010', 36)
# Inserting row 39 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'SREE LEKYAA TRAVELS', 'NON A/C Sleeper (2+1)', '21:50', '10h 55m', '08:45', 3.2, '0', 17)
# Inserting row 40 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Sri Krishna Travels', 'A/C Sleeper (2+1)', '18:05', '12h 25m', '06:30', 3.9, '1150', 3)
# Inserting row 41 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'V Kaveri Travels', 'VE A/C Sleeper (2+1)', '18:15', '13h 15m', '07:30', 3.8, '899', 8)
# Inserting row 42 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Jagan Travels', 'A/C Sleeper (2+1)', '22:05', '11h 40m', '09:45', 3.8, '9', 6)
# Inserting row 43 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Orange Tours And Travels', 'A/C Sleeper (2+1)', '18:15', '11h 30m', '05:45', 3.1, '999', 5)
# Inserting row 44 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Balaji Cabs', 'Bharat Benz A/C Sleeper (2+1)', '18:30', '09h 00m', '03:30', 3.8, '5', 2)
# Inserting row 45 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Zingbus Plus', 'A/C Sleeper (2+1)', '21:00', '11h 20m', '08:20', 3.9, '2499', 8)
# Inserting row 46 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Vandana Travels', 'NON A/C Sleeper (2+1)', '21:15', '11h 45m', '09:00', 3.4, '4999', 5)
# Inserting row 47 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Mozo travels', 'A/C Sleeper (2+1)', '18:05', '12h 55m', '07:00', 3.5, '1050', 6)
# Inserting row 48 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Balaji Cabs', 'Bharat Benz A/C Sleeper (2+1)', '18:15', '07h 45m', '02:00', 3.8, '2', 8)
# Inserting row 49 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'True Bus', 'Volvo Multi Axle B9R A/C Sleeper (2+1)', '18:10', '10h 50m', '05:00', 3.9, '999', 1)
# Inserting row 50 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'VEGA BUS', 'A/C Seater / Sleeper (2+1)', '22:15', '11h 30m', '09:45', 3.1, '950', 1)
# Inserting row 51 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Mahi Trans Solutions', 'A/C Sleeper (2+1)', '18:50', '12h 25m', '07:15', 3.7, '1100', 1)
# Inserting row 52 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Mahi Trans Solutions', 'A/C Sleeper (2+1)', '18:45', '12h 30m', '07:15', 3.7, '2', 1)
# Inserting row 53 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Meghana Travels', 'A/C Sleeper (2+1)', '21:50', '11h 10m', '09:00', 2.3, '1000', 13)
# Inserting row 54 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'PMR Express', 'A/C Sleeper (2+1)', '19:00', '12h 30m', '07:30', 2.6, '1090', 22)
# Inserting row 55 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'DHANUNJAYA TRAVELS', 'A/C Sleeper (2+1)', '20:00', '12h 35m', '08:35', 1.6, '990', 14)
# Inserting row 56 for Hyderabad to Tirupati - Government
# ('TSRTC-Telangana State Transport', 'Hyderabad to Tirupati', 'Government', 'Vandana Travels', 'A/C Seater / Sleeper (2+1)', '21:10', '11h 50m', '09:00', 2.3, '1100', 16)

# %%
import pandas as pd

# Assuming 'TSRTC_data' is a dictionary containing the scraped data
assam_data =pd.read_json("C:/Users/yuvanelson/Documents/Rebbus-Project-1-main/Rebbus-Project-1-main/ASTC.json") # Change read_csv to read_json
andhar_data =pd.read_json("C:/Users/yuvanelson/Documents/Rebbus-Project-1-main/Rebbus-Project-1-main/APSRTC.json")
haryana_data =pd.read_json("C:/Users/yuvanelson/Documents/Rebbus-Project-1-main/Rebbus-Project-1-main/HRTC.json")
uttar_data =pd.read_json("C:/Users/yuvanelson/Documents/Rebbus-Project-1-main/Rebbus-Project-1-main/UPSRTC.json")
south_data =pd.read_json("C:/Users/yuvanelson/Documents/Rebbus-Project-1-main/Rebbus-Project-1-main/SBSTC.json")
kerala_data =pd.read_json("C:/Users/yuvanelson/Documents/Rebbus-Project-1-main/Rebbus-Project-1-main/Kerala.json")
jammu_data =pd.read_json("C:/Users/yuvanelson/Documents/Rebbus-Project-1-main/Rebbus-Project-1-main/JKSRTC.json")

# %%
#Inputing the arguments State bus name,Variable containing scraped data,Table name,Database name
importer = Importing('ASTC-Assam State Transport', assam_data, "Bus_Data", "RedBus")
importer = Importing('APSRTC-Andhra Pradesh State Transport', andhar_data, "Bus_Data", "RedBus")
importer = Importing('HRTC-Haryana State Transport', haryana_data, "Bus_Data", "RedBus")
importer = Importing('UPSRTC-Uttar Pradesh State Transport', uttar_data, "Bus_Data", "RedBus")
importer = Importing('SBSTC-South Bengal State Transport', south_data, "Bus_Data", "RedBus")
importer = Importing('kerala-kerala State Transport', kerala_data, "Bus_Data", "RedBus")
importer = Importing('JKSRTC-Jammu and Kashmir State Road Transport Corporation', jammu_data, "Bus_Data", "RedBus")
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x000001F7352241A0>
# Inserting data for operator type: Private on route: Tezpur to Guwahati
# Minimum length of lists: 3
# Inserting row 1 for Tezpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Tezpur to Guwahati', 'Private', 'Assam State Transport Corporation (ASTC) - 157959', 'Bharat Benz A/C Seater (2+2)', '14:00', '04h 30m', '18:30', 4.3, '298', 12)
# Inserting row 2 for Tezpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Tezpur to Guwahati', 'Private', 'Orient Transline', 'A/C Seater (2+1)', '07:35', '03h 25m', '11:00', 3.7, '342.86', 18)
# Inserting row 3 for Tezpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Tezpur to Guwahati', 'Private', 'WARISPIYA TRAVELS', 'AC Seater (2+2)', '07:45', '04h 15m', '12:00', 4.2, '360', 35)
# Inserting data for operator type: Government on route: Tezpur to Guwahati
# KeyError: 'Bus_Name' in route Tezpur to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Guwahati to Tezpur
# Minimum length of lists: 8
# Inserting row 1 for Guwahati to Tezpur - Private
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Private', 'SHIVAM TRAVELS', 'Bharat Benz A/C Seater (2+1)', '07:15', '03h 55m', '11:10', 4.4, '356.23', 30)
# Inserting row 2 for Guwahati to Tezpur - Private
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Private', 'Chartered Bus - ASTC', 'A/C Seater Push Back (2+2)', '07:15', '03h 45m', '11:00', 4.6, '389.13', 34)
# Inserting row 3 for Guwahati to Tezpur - Private
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Private', 'Chartered Bus - ASTC', 'Volvo AC Seater Pushback 2+2', '07:30', '04h 00m', '11:30', 4.7, '389.13', 31)
# Inserting row 4 for Guwahati to Tezpur - Private
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Private', 'Chartered Bus - ASTC', 'Volvo AC Seater Pushback 2+2', '07:30', '03h 00m', '10:30', 4.5, '432.06', 32)
# Inserting row 5 for Guwahati to Tezpur - Private
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Private', 'Chartered Bus - ASTC', 'Volvo AC Seater Pushback 2+2', '08:30', '04h 00m', '12:30', 4.6, '300', 31)
# Inserting row 6 for Guwahati to Tezpur - Private
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Private', 'NEELKANTH TRAVELS', 'A/C Seater Push Back (2+2)', '09:05', '05h 25m', '14:30', 4.5, '328.5', 35)
# Inserting row 7 for Guwahati to Tezpur - Private
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Private', 'MAA Anada (UNDER ASTC)', 'AC Seater (2+2)', '09:30', '05h 15m', '14:45', 3.3, '380.95', 11)
# Inserting row 8 for Guwahati to Tezpur - Private
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Private', 'Mahi Travels(Under ASTC)', 'A/C Seater (2+2)', '10:00', '05h 00m', '15:00', 4.2, '380.95', 19)
# Inserting data for operator type: Government on route: Guwahati to Tezpur
# Minimum length of lists: 8
# Inserting row 1 for Guwahati to Tezpur - Government
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Government', 'Assam State Transport Corporation (ASTC) - 173419', 'Bharat Benz A/C Seater (2+2)', '07:15', '03h 35m', '10:50', 3.5, '298', 30)
# Inserting row 2 for Guwahati to Tezpur - Government
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Government', 'Assam State Transport Corporation (ASTC) - 143955', 'Bharat Benz A/C Seater (2+2)', '07:30', '03h 30m', '11:00', 4.3, '298', 34)
# Inserting row 3 for Guwahati to Tezpur - Government
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Government', 'Assam State Transport Corporation (ASTC) - 175310', 'Bharat Benz A/C Seater (2+2)', '08:30', '04h 15m', '12:45', 4.4, '298', 31)
# Inserting row 4 for Guwahati to Tezpur - Government
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Government', 'Assam State Transport Corporation (ASTC) - 154910', 'Bharat Benz A/C Seater (2+2)', '10:30', '04h 30m', '15:00', 3.7, '298', 32)
# Inserting row 5 for Guwahati to Tezpur - Government
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Government', 'Assam State Transport Corporation (ASTC) - 139720', 'Volvo AC Seater 2+2', '13:45', '04h 15m', '18:00', 3.6, '298', 31)
# Inserting row 6 for Guwahati to Tezpur - Government
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Government', 'Assam State Transport Corporation (ASTC) - 174839', 'Bharat Benz A/C Seater (2+2)', '15:15', '04h 00m', '19:15', 3.9, '298', 35)
# Inserting row 7 for Guwahati to Tezpur - Government
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Government', 'SHIVAM TRAVELS', 'Bharat Benz A/C Seater (2+1)', '07:15', '03h 55m', '11:10', 4.4, '356.23', 11)
# Inserting row 8 for Guwahati to Tezpur - Government
# ('ASTC-Assam State Transport', 'Guwahati to Tezpur', 'Government', 'Chartered Bus - ASTC', 'A/C Seater Push Back (2+2)', '07:15', '03h 45m', '11:00', 4.6, '389.13', 19)
# Inserting data for operator type: Private on route: Nagaon (Assam) to Guwahati
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Nagaon (Assam) to Guwahati
# KeyError: 'Bus_Name' in route Nagaon (Assam) to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Guwahati to Nagaon (Assam)
# Minimum length of lists: 1
# Inserting row 1 for Guwahati to Nagaon (Assam) - Private
# ('ASTC-Assam State Transport', 'Guwahati to Nagaon (Assam)', 'Private', 'SHIVAM TRAVELS', 'Bharat Benz A/C Seater (2+1)', '07:15', '02h 15m', '09:30', 4.3, '270.01', 23)
# Inserting data for operator type: Government on route: Guwahati to Nagaon (Assam)
# Minimum length of lists: 1
# Inserting row 1 for Guwahati to Nagaon (Assam) - Government
# ('ASTC-Assam State Transport', 'Guwahati to Nagaon (Assam)', 'Government', 'Assam State Transport Corporation (ASTC) - 154910', 'Bharat Benz A/C Seater (2+2)', '10:30', '02h 30m', '13:00', 3.9, '191', 23)
# Inserting data for operator type: Private on route: Goalpara to Guwahati
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Goalpara to Guwahati
# KeyError: 'Bus_Name' in route Goalpara to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jorhat to North Lakhimpur
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jorhat to North Lakhimpur
# KeyError: 'Bus_Name' in route Jorhat to North Lakhimpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Dhubri to Guwahati
# Minimum length of lists: 2
# Inserting row 1 for Dhubri to Guwahati - Private
# ('ASTC-Assam State Transport', 'Dhubri to Guwahati', 'Private', 'Yatra', 'Non AC Seater (2+2)', '20:15', '07h 15m', '03:30', 2.6, '350', 40)
# Inserting row 2 for Dhubri to Guwahati - Private
# ('ASTC-Assam State Transport', 'Dhubri to Guwahati', 'Private', 'Yatra', 'Non AC Seater (2+2)', '11:15', '07h 30m', '18:45', 1.7000000000000002, '300', 38)
# Inserting data for operator type: Government on route: Dhubri to Guwahati
# KeyError: 'Bus_Name' in route Dhubri to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Guwahati to Dhubri
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Guwahati to Dhubri
# KeyError: 'Bus_Name' in route Guwahati to Dhubri for operator type Government. Skipping...
# Inserting data for operator type: Private on route: North Lakhimpur to Sibsagar
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: North Lakhimpur to Sibsagar
# KeyError: 'Bus_Name' in route North Lakhimpur to Sibsagar for operator type Government. Skipping...
# Inserting data for operator type: Private on route: North Lakhimpur to Jorhat
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: North Lakhimpur to Jorhat
# KeyError: 'Bus_Name' in route North Lakhimpur to Jorhat for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Dhekiajuli to Guwahati
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Dhekiajuli to Guwahati
# KeyError: 'Bus_Name' in route Dhekiajuli to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jorhat to Dibrugarh
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jorhat to Dibrugarh
# KeyError: 'Bus_Name' in route Jorhat to Dibrugarh for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jorhat to Dhemaji
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jorhat to Dhemaji
# KeyError: 'Bus_Name' in route Jorhat to Dhemaji for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Sibsagar to North Lakhimpur
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Sibsagar to North Lakhimpur
# KeyError: 'Bus_Name' in route Sibsagar to North Lakhimpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Dhemaji to Jorhat
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Dhemaji to Jorhat
# KeyError: 'Bus_Name' in route Dhemaji to Jorhat for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Tezpur to Dibrugarh
# Minimum length of lists: 8
# Inserting row 1 for Tezpur to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Tezpur to Dibrugarh', 'Private', 'Assam State Transport Corporation (ASTC) - 96880', 'A/C Seater (2+1)', '08:00', '08h 00m', '16:00', 3.4, '463', 17)
# Inserting row 2 for Tezpur to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Tezpur to Dibrugarh', 'Private', 'Aniruddha Travels', 'AC Seater (2+2)', '07:50', '08h 25m', '16:15', 3.7, '550', 25)
# Inserting row 3 for Tezpur to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Tezpur to Dibrugarh', 'Private', 'Aniruddha Travels', 'NON A/C Seater/ Sleeper (2+1)', '19:30', '08h 30m', '04:00', 3.5, '550', 48)
# Inserting row 4 for Tezpur to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Tezpur to Dibrugarh', 'Private', 'Puja Transport', 'Non AC Seater (2+2)', '20:00', '09h 00m', '05:00', 2.4, '550', 16)
# Inserting row 5 for Tezpur to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Tezpur to Dibrugarh', 'Private', 'SANJEEBANI TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '21:30', '06h 30m', '04:00', 3.0, '550', 32)
# Inserting row 6 for Tezpur to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Tezpur to Dibrugarh', 'Private', 'Puja Transport', 'NON AC Seater / Sleeper 2+1', '20:00', '08h 30m', '04:30', 3.6, '550', 30)
# Inserting row 7 for Tezpur to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Tezpur to Dibrugarh', 'Private', 'J.S. Travels', 'Non AC Seater (2+1)', '21:00', '07h 00m', '04:00', 2.3, '650', 35)
# Inserting row 8 for Tezpur to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Tezpur to Dibrugarh', 'Private', 'Maa Laxmi', 'NON A/C Seater Push Back (2+1)', '22:15', '07h 15m', '05:30', 2.5, '470', 45)
# Inserting data for operator type: Government on route: Tezpur to Dibrugarh
# KeyError: 'Bus_Name' in route Tezpur to Dibrugarh for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Haflong to Guwahati
# Minimum length of lists: 1
# Inserting row 1 for Haflong to Guwahati - Private
# ('ASTC-Assam State Transport', 'Haflong to Guwahati', 'Private', 'Deep Travels', 'Non AC Seater (2+1)', '17:45', '10h 45m', '04:30', 4.1, '600', 29)
# Inserting data for operator type: Government on route: Haflong to Guwahati
# KeyError: 'Bus_Name' in route Haflong to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: North Lakhimpur to Dibrugarh
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: North Lakhimpur to Dibrugarh
# KeyError: 'Bus_Name' in route North Lakhimpur to Dibrugarh for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jorhat to Tinsukia
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jorhat to Tinsukia
# Minimum length of lists: 0
# Inserting data for operator type: Private on route: Dibrugarh to Tezpur
# Minimum length of lists: 5
# Inserting row 1 for Dibrugarh to Tezpur - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Tezpur', 'Private', 'Aniruddha Travels', 'AC Seater (2+2)', '07:30', '08h 05m', '15:35', 4.5, '550', 15)
# Inserting row 2 for Dibrugarh to Tezpur - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Tezpur', 'Private', 'Puja Transport', 'NON AC Seater / Sleeper 2+1', '20:00', '09h 00m', '05:00', 3.6, '470', 39)
# Inserting row 3 for Dibrugarh to Tezpur - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Tezpur', 'Private', 'SANJEEBANI TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '18:45', '08h 15m', '03:00', 3.0, '500', 42)
# Inserting row 4 for Dibrugarh to Tezpur - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Tezpur', 'Private', 'PIHU TRANSPORT', 'Bharat Benz NON A/C Seater / Sleeper (2+1)', '19:50', '08h 40m', '04:30', 2.7, '550', 32)
# Inserting row 5 for Dibrugarh to Tezpur - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Tezpur', 'Private', 'J.S. Travels', 'Non AC Seater (2+1)', '19:00', '09h 00m', '04:00', 3.2, '650', 30)
# Inserting data for operator type: Government on route: Dibrugarh to Tezpur
# KeyError: 'Bus_Name' in route Dibrugarh to Tezpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Guwahati to Biswanath Charali
# Minimum length of lists: 10
# Inserting row 1 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'Chartered Bus - ASTC', 'A/C Seater Push Back (2+2)', '07:30', '04h 30m', '12:00', 4.6, '551.37', 28)
# Inserting row 2 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'KIRAN TRAVELS', 'A/C Seater (2+1)', '07:30', '05h 00m', '12:30', 3.0, '500', 30)
# Inserting row 3 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'Pranjit Travels (Under ASTC)', 'Non AC Seater (2+1)', '07:45', '07h 15m', '15:00', 3.7, '550', 34)
# Inserting row 4 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'Pranjit Travels (Under ASTC)', 'A/C Seater (2+1)', '08:15', '07h 00m', '15:15', 4.8, '400', 31)
# Inserting row 5 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'BLUE HILL TRAVELS INDIA LIMITED', 'NON A/C Seater Semi Sleeper (2+1)', '09:30', '05h 30m', '15:00', 3.5, '476.19', 22)
# Inserting row 6 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'Mahi Travels(Under ASTC)', 'A/C Seater (2+2)', '10:00', '06h 30m', '16:30', 4.2, '476.19', 19)
# Inserting row 7 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'Orient Transline', 'A/C Seater (2+1)', '11:30', '05h 10m', '16:40', 4.1, '410', 32)
# Inserting row 8 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'Orient Transline', 'A/C Seater (2+1)', '13:00', '06h 10m', '19:10', 3.5, '500', 23)
# Inserting row 9 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'Mahalaxmi Travels', 'Tata A/C Seater (2+2)', '14:35', '05h 25m', '20:00', 4.3, '600', 31)
# Inserting row 10 for Guwahati to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Private', 'PARIJAT TRAVELS(UNDER ASTC)', 'NON A/C Seater (2+1)', '19:35', '06h 25m', '02:00', 4.3, '500', 25)
# Inserting data for operator type: Government on route: Guwahati to Biswanath Charali
# Minimum length of lists: 10
# Inserting row 1 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'Assam State Transport Corporation (ASTC) - 173419', 'Bharat Benz A/C Seater (2+2)', '07:45', '04h 05m', '11:50', 3.6, '412', 28)
# Inserting row 2 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'Assam State Transport Corporation (ASTC) - 175310', 'Bharat Benz A/C Seater (2+2)', '08:30', '05h 15m', '13:45', 3.8, '412', 30)
# Inserting row 3 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'Chartered Bus - ASTC', 'A/C Seater Push Back (2+2)', '07:30', '04h 30m', '12:00', 4.6, '551.37', 34)
# Inserting row 4 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'KIRAN TRAVELS', 'A/C Seater (2+1)', '07:30', '05h 00m', '12:30', 3.0, '500', 31)
# Inserting row 5 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'Pranjit Travels (Under ASTC)', 'Non AC Seater (2+1)', '07:45', '07h 15m', '15:00', 3.7, '550', 22)
# Inserting row 6 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'Pranjit Travels (Under ASTC)', 'A/C Seater (2+1)', '08:15', '07h 00m', '15:15', 4.8, '400', 19)
# Inserting row 7 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'BLUE HILL TRAVELS INDIA LIMITED', 'NON A/C Seater Semi Sleeper (2+1)', '09:30', '05h 30m', '15:00', 3.5, '476.19', 32)
# Inserting row 8 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'Mahi Travels(Under ASTC)', 'A/C Seater (2+2)', '10:00', '06h 30m', '16:30', 4.2, '476.19', 23)
# Inserting row 9 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'Orient Transline', 'A/C Seater (2+1)', '11:30', '05h 10m', '16:40', 4.1, '410', 31)
# Inserting row 10 for Guwahati to Biswanath Charali - Government
# ('ASTC-Assam State Transport', 'Guwahati to Biswanath Charali', 'Government', 'Orient Transline', 'A/C Seater (2+1)', '13:00', '06h 10m', '19:10', 3.5, '500', 25)
# Inserting data for operator type: Private on route: Guwahati to Haflong
# Minimum length of lists: 1
# Inserting row 1 for Guwahati to Haflong - Private
# ('ASTC-Assam State Transport', 'Guwahati to Haflong', 'Private', 'NETWORK TRAVELS', 'NON A/C Seater (2+1)', '18:30', '12h 30m', '07:00', 4.6, '600', 17)
# Inserting data for operator type: Government on route: Guwahati to Haflong
# KeyError: 'Bus_Name' in route Guwahati to Haflong for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Dibrugarh to North Lakhimpur
# Minimum length of lists: 2
# Inserting row 1 for Dibrugarh to North Lakhimpur - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to North Lakhimpur', 'Private', 'Assam State Transport Corporation (ASTC) - 147556', 'Bharat Benz A/C Seater (2+2)', '12:30', '03h 15m', '15:45', 4.3, '235.62', 37)
# Inserting row 2 for Dibrugarh to North Lakhimpur - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to North Lakhimpur', 'Private', 'BARBIE TRAVELS', 'NON A/C Hi-Tech Push Back (2+2)', '11:10', '04h 20m', '15:30', 2.6, '240', 34)
# Inserting data for operator type: Government on route: Dibrugarh to North Lakhimpur
# KeyError: 'Bus_Name' in route Dibrugarh to North Lakhimpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Nagaon (Assam) to Haflong
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Nagaon (Assam) to Haflong
# KeyError: 'Bus_Name' in route Nagaon (Assam) to Haflong for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Tezpur to Moran
# Minimum length of lists: 4
# Inserting row 1 for Tezpur to Moran - Private
# ('ASTC-Assam State Transport', 'Tezpur to Moran', 'Private', 'Assam State Transport Corporation (ASTC) - 96880', 'A/C Seater (2+1)', '08:00', '06h 45m', '14:45', 3.9, '405', 48)
# Inserting row 2 for Tezpur to Moran - Private
# ('ASTC-Assam State Transport', 'Tezpur to Moran', 'Private', 'Aniruddha Travels', 'AC Seater (2+2)', '07:50', '07h 10m', '15:00', 3.3, '520', 45)
# Inserting row 3 for Tezpur to Moran - Private
# ('ASTC-Assam State Transport', 'Tezpur to Moran', 'Private', 'SANJEEBANI TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '21:30', '05h 30m', '03:00', 2.8, '500', 30)
# Inserting row 4 for Tezpur to Moran - Private
# ('ASTC-Assam State Transport', 'Tezpur to Moran', 'Private', 'PIHU TRANSPORT', 'Bharat Benz NON A/C Seater / Sleeper (2+1)', '19:45', '07h 15m', '03:00', 1.8, '650', 35)
# Inserting data for operator type: Government on route: Tezpur to Moran
# KeyError: 'Bus_Name' in route Tezpur to Moran for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Dibrugarh to Jorhat
# Minimum length of lists: 1
# Inserting row 1 for Dibrugarh to Jorhat - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Jorhat', 'Private', 'Assam State Transport Corporation (ASTC) - 166134', 'Bharat Benz A/C Seater (2+2)', '10:30', '05h 00m', '15:30', 3.8, '207', 42)
# Inserting data for operator type: Government on route: Dibrugarh to Jorhat
# KeyError: 'Bus_Name' in route Dibrugarh to Jorhat for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Guwahati to Silchar
# Minimum length of lists: 4
# Inserting row 1 for Guwahati to Silchar - Private
# ('ASTC-Assam State Transport', 'Guwahati to Silchar', 'Private', 'RAYAN TRAVELS', 'NON A/C Seater (2+1)', '18:30', '10h 45m', '05:15', 2.8, '650', 32)
# Inserting row 2 for Guwahati to Silchar - Private
# ('ASTC-Assam State Transport', 'Guwahati to Silchar', 'Private', 'JAYSIKA', 'NON A/C Seater (2+1)', '18:30', '11h 30m', '06:00', 2.2, '650', 32)
# Inserting row 3 for Guwahati to Silchar - Private
# ('ASTC-Assam State Transport', 'Guwahati to Silchar', 'Private', 'SEEMA TRAVELS', 'NON AC Seater / Sleeper 2+1', '19:00', '10h 00m', '05:00', 1.5, '650', 46)
# Inserting row 4 for Guwahati to Silchar - Private
# ('ASTC-Assam State Transport', 'Guwahati to Silchar', 'Private', 'Bholanath Travels', 'NON AC Seater / Sleeper 2+1', '19:30', '09h 30m', '05:00', 1.0, '650', 34)
# Inserting data for operator type: Government on route: Guwahati to Silchar
# KeyError: 'Bus_Name' in route Guwahati to Silchar for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Bihpuria to Dibrugarh
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Bihpuria to Dibrugarh
# KeyError: 'Bus_Name' in route Bihpuria to Dibrugarh for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Haflong to Nagaon (Assam)
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Haflong to Nagaon (Assam)
# KeyError: 'Bus_Name' in route Haflong to Nagaon (Assam) for operator type Government. Skipping...
# Inserting data for operator type: Private on route: North Lakhimpur to Tezpur
# Minimum length of lists: 1
# Inserting row 1 for North Lakhimpur to Tezpur - Private
# ('ASTC-Assam State Transport', 'North Lakhimpur to Tezpur', 'Private', 'Chartered Bus - ASTC', 'A/C Seater Push Back (2+2)', '07:45', '03h 45m', '11:30', 4.5, '541.16', 25)
# Inserting data for operator type: Government on route: North Lakhimpur to Tezpur
# KeyError: 'Bus_Name' in route North Lakhimpur to Tezpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Biswanath Charali to Guwahati
# Minimum length of lists: 4
# Inserting row 1 for Biswanath Charali to Guwahati - Private
# ('ASTC-Assam State Transport', 'Biswanath Charali to Guwahati', 'Private', 'Mahalaxmi Travels', 'Tata A/C Seater (2+2)', '08:10', '05h 35m', '13:45', 3.4, '410', 10)
# Inserting row 2 for Biswanath Charali to Guwahati - Private
# ('ASTC-Assam State Transport', 'Biswanath Charali to Guwahati', 'Private', 'Pranjit Travels (Under ASTC)', 'Non AC Seater (2+1)', '09:00', '06h 00m', '15:00', 3.4, '500', 29)
# Inserting row 3 for Biswanath Charali to Guwahati - Private
# ('ASTC-Assam State Transport', 'Biswanath Charali to Guwahati', 'Private', 'MAHARATHI TRANSPORT', 'NON A/C Semi Sleeper (2+1)', '09:45', '06h 15m', '16:00', 3.6, '500', 33)
# Inserting row 4 for Biswanath Charali to Guwahati - Private
# ('ASTC-Assam State Transport', 'Biswanath Charali to Guwahati', 'Private', 'Pranjit Travels (Under ASTC)', 'A/C Seater (2+1)', '10:30', '05h 00m', '15:30', 3.6, '550', 18)
# Inserting data for operator type: Government on route: Biswanath Charali to Guwahati
# KeyError: 'Bus_Name' in route Biswanath Charali to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Biswanath Charali to Dibrugarh
# Minimum length of lists: 1
# Inserting row 1 for Biswanath Charali to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Biswanath Charali to Dibrugarh', 'Private', 'Air Bus Travels', 'NON AC Seater / Sleeper 2+1', '18:30', '07h 30m', '02:00', 3.2, '500', 44)
# Inserting data for operator type: Government on route: Biswanath Charali to Dibrugarh
# KeyError: 'Bus_Name' in route Biswanath Charali to Dibrugarh for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Tinsukia to Jorhat
# Minimum length of lists: 1
# Inserting row 1 for Tinsukia to Jorhat - Private
# ('ASTC-Assam State Transport', 'Tinsukia to Jorhat', 'Private', 'NETWORK TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '17:00', '06h 00m', '23:00', 4.3, '400', 40)
# Inserting data for operator type: Government on route: Tinsukia to Jorhat
# Minimum length of lists: 2
# Inserting row 1 for Tinsukia to Jorhat - Government
# ('ASTC-Assam State Transport', 'Tinsukia to Jorhat', 'Government', 'Assam State Transport Corporation (ASTC) - 139496', 'NON A/C Seater Push Back (2+1)', '08:25', '05h 05m', '13:30', 3.3, '245', 40)
# Inserting row 2 for Tinsukia to Jorhat - Government
# ('ASTC-Assam State Transport', 'Tinsukia to Jorhat', 'Government', 'Assam State Transport Corporation (ASTC) - 166134', 'Bharat Benz A/C Seater (2+2)', '09:00', '06h 30m', '15:30', 4.0, '281', 33)
# Inserting data for operator type: Private on route: Moran to Tezpur
# Minimum length of lists: 3
# Inserting row 1 for Moran to Tezpur - Private
# ('ASTC-Assam State Transport', 'Moran to Tezpur', 'Private', 'Aniruddha Travels', 'AC Seater (2+2)', '08:25', '07h 10m', '15:35', 4.4, '520', 43)
# Inserting row 2 for Moran to Tezpur - Private
# ('ASTC-Assam State Transport', 'Moran to Tezpur', 'Private', 'PIHU TRANSPORT', 'Bharat Benz NON A/C Seater / Sleeper (2+1)', '20:45', '07h 45m', '04:30', 2.6, '500', 50)
# Inserting row 3 for Moran to Tezpur - Private
# ('ASTC-Assam State Transport', 'Moran to Tezpur', 'Private', 'SANJEEBANI TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '20:15', '06h 45m', '03:00', 2.8, '650', 36)
# Inserting data for operator type: Government on route: Moran to Tezpur
# KeyError: 'Bus_Name' in route Moran to Tezpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jorhat to Gogamukh
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jorhat to Gogamukh
# KeyError: 'Bus_Name' in route Jorhat to Gogamukh for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Dibrugarh to Biswanath Charali
# Minimum length of lists: 1
# Inserting row 1 for Dibrugarh to Biswanath Charali - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Biswanath Charali', 'Private', 'Air Bus Travels', 'NON AC Seater / Sleeper 2+1', '19:40', '09h 20m', '05:00', 3.7, '500', 37)
# Inserting data for operator type: Government on route: Dibrugarh to Biswanath Charali
# KeyError: 'Bus_Name' in route Dibrugarh to Biswanath Charali for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Gohpur to Guwahati
# Minimum length of lists: 12
# Inserting row 1 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Yatra Travels', 'NON A/C Seater (2+1)', '09:00', '08h 00m', '17:00', 4.4, '570', 20)
# Inserting row 2 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Pranjit Travels (Under ASTC)', 'Non AC Seater (2+1)', '08:00', '07h 00m', '15:00', 4.4, '620', 37)
# Inserting row 3 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'KIRAN TRAVELS', 'A/C Seater (2+1)', '22:50', '08h 40m', '07:30', 4.3, '551.37', 32)
# Inserting row 4 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Pranjit Travels (Under ASTC)', 'A/C Seater / Sleeper (2+1)', '23:05', '06h 55m', '06:00', 4.6, '500', 32)
# Inserting row 5 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Yatra Travels', 'NON AC Seater/ Sleeper (2+1)', '22:20', '07h 40m', '06:00', 4.4, '499', 22)
# Inserting row 6 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Chartered Bus - ASTC', 'A/C Seater Push Back (2+2)', '09:30', '06h 45m', '16:15', 4.2, '500', 24)
# Inserting row 7 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'BARBIE TRAVELS', 'A/C Seater Push Back (2+2)', '10:20', '07h 30m', '17:50', 3.9, '570', 32)
# Inserting row 8 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Deep Travels', 'NON AC Seater / Sleeper 2+1', '22:20', '06h 40m', '05:00', 3.1, '570', 32)
# Inserting row 9 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Pranjit Travels (Under ASTC)', 'Bharat Benz A/C Seater (2+1)', '22:45', '07h 30m', '06:15', 3.2, '500', 32)
# Inserting row 10 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'PARIJAT TRAVELS(UNDER ASTC)', 'NON A/C Seater (2+1)', '23:11', '07h 19m', '06:30', 3.6, '550', 32)
# Inserting row 11 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Yatra Travels', 'NON A/C Seater (2+1)', '22:35', '07h 40m', '06:15', 3.0, '570', 35)
# Inserting row 12 for Gohpur to Guwahati - Private
# ('ASTC-Assam State Transport', 'Gohpur to Guwahati', 'Private', 'Drishti Travels', 'NON A/C Seater (2+1)', '21:00', '08h 30m', '05:30', 3.2, '630', 33)
# Inserting data for operator type: Government on route: Gohpur to Guwahati
# KeyError: 'Bus_Name' in route Gohpur to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Tinsukia to Tezpur
# Minimum length of lists: 4
# Inserting row 1 for Tinsukia to Tezpur - Private
# ('ASTC-Assam State Transport', 'Tinsukia to Tezpur', 'Private', 'Puja Transport', 'NON AC Seater / Sleeper 2+1', '18:30', '10h 30m', '05:00', 3.7, '600', 13)
# Inserting row 2 for Tinsukia to Tezpur - Private
# ('ASTC-Assam State Transport', 'Tinsukia to Tezpur', 'Private', 'J.S. Travels', 'Non AC Seater (2+1)', '17:30', '10h 30m', '04:00', 3.1, '550', 32)
# Inserting row 3 for Tinsukia to Tezpur - Private
# ('ASTC-Assam State Transport', 'Tinsukia to Tezpur', 'Private', 'SANJEEBANI TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '16:40', '10h 20m', '03:00', 1.7000000000000002, '550', 38)
# Inserting row 4 for Tinsukia to Tezpur - Private
# ('ASTC-Assam State Transport', 'Tinsukia to Tezpur', 'Private', 'MOON TRAVELS', 'AC Seater (2+2)', '07:45', '09h 15m', '17:00', 2.8, '650', 30)
# Inserting data for operator type: Government on route: Tinsukia to Tezpur
# KeyError: 'Bus_Name' in route Tinsukia to Tezpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: North Lakhimpur to Golaghat
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: North Lakhimpur to Golaghat
# KeyError: 'Bus_Name' in route North Lakhimpur to Golaghat for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Golaghat to North Lakhimpur
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Golaghat to North Lakhimpur
# KeyError: 'Bus_Name' in route Golaghat to North Lakhimpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Silchar to Guwahati
# Minimum length of lists: 5
# Inserting row 1 for Silchar to Guwahati - Private
# ('ASTC-Assam State Transport', 'Silchar to Guwahati', 'Private', 'Assam State Transport Corporation (ASTC) - 139638', 'NON A/C Seater Push Back (2+1)', '16:45', '13h 00m', '05:45', 2.3, '547', 26)
# Inserting row 2 for Silchar to Guwahati - Private
# ('ASTC-Assam State Transport', 'Silchar to Guwahati', 'Private', 'Jagannath Travels and Tours Pvt. Ltd.', 'NON A/C Seater Push Back (2+1)', '18:30', '10h 35m', '05:05', 2.0, '650', 28)
# Inserting row 3 for Silchar to Guwahati - Private
# ('ASTC-Assam State Transport', 'Silchar to Guwahati', 'Private', 'Bholanath Travels', 'NON AC Seater / Sleeper 2+1', '18:35', '11h 25m', '06:00', 2.8, '600', 46)
# Inserting row 4 for Silchar to Guwahati - Private
# ('ASTC-Assam State Transport', 'Silchar to Guwahati', 'Private', 'RAYAN TRAVELS', 'NON A/C Seater (2+1)', '18:30', '11h 30m', '06:00', 2.9, '650', 32)
# Inserting row 5 for Silchar to Guwahati - Private
# ('ASTC-Assam State Transport', 'Silchar to Guwahati', 'Private', 'NETWORK TRAVELS', 'NON A/C Seater Push Back (2+1)', '17:30', '12h 00m', '05:30', 2.5, '550', 32)
# Inserting data for operator type: Government on route: Silchar to Guwahati
# KeyError: 'Bus_Name' in route Silchar to Guwahati for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Bokakhat to Dibrugarh
# Minimum length of lists: 2
# Inserting row 1 for Bokakhat to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Bokakhat to Dibrugarh', 'Private', 'MOON TRAVELS', 'AC Seater (2+2)', '09:45', '05h 35m', '15:20', 3.1, '735.16', 18)
# Inserting row 2 for Bokakhat to Dibrugarh - Private
# ('ASTC-Assam State Transport', 'Bokakhat to Dibrugarh', 'Private', 'Aniruddha Travels', 'AC Seater (2+2)', '10:15', '06h 00m', '16:15', 4.2, '550', 46)
# Inserting data for operator type: Government on route: Bokakhat to Dibrugarh
# KeyError: 'Bus_Name' in route Bokakhat to Dibrugarh for operator type Government. Skipping...
# Inserting data for operator type: Private on route: North Lakhimpur to Moran
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: North Lakhimpur to Moran
# KeyError: 'Bus_Name' in route North Lakhimpur to Moran for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Tezpur to North Lakhimpur
# Minimum length of lists: 1
# Inserting row 1 for Tezpur to North Lakhimpur - Private
# ('ASTC-Assam State Transport', 'Tezpur to North Lakhimpur', 'Private', 'Assam State Transport Corporation (ASTC) - 173419', 'Bharat Benz A/C Seater (2+2)', '10:50', '04h 10m', '15:00', 2.9, '334', 23)
# Inserting data for operator type: Government on route: Tezpur to North Lakhimpur
# KeyError: 'Bus_Name' in route Tezpur to North Lakhimpur for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Tezpur to Tinsukia
# Minimum length of lists: 8
# Inserting row 1 for Tezpur to Tinsukia - Private
# ('ASTC-Assam State Transport', 'Tezpur to Tinsukia', 'Private', 'Assam State Transport Corporation (ASTC) - 96880', 'A/C Seater (2+1)', '08:00', '09h 45m', '17:45', 3.3, '540', 25)
# Inserting row 2 for Tezpur to Tinsukia - Private
# ('ASTC-Assam State Transport', 'Tezpur to Tinsukia', 'Private', 'Aniruddha Travels', 'AC Seater (2+2)', '07:50', '09h 40m', '17:30', 3.4, '550', 48)
# Inserting row 3 for Tezpur to Tinsukia - Private
# ('ASTC-Assam State Transport', 'Tezpur to Tinsukia', 'Private', 'Puja Transport', 'Non AC Seater (2+2)', '20:00', '10h 00m', '06:00', 3.3, '550', 17)
# Inserting row 4 for Tezpur to Tinsukia - Private
# ('ASTC-Assam State Transport', 'Tezpur to Tinsukia', 'Private', 'SANJEEBANI TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '21:30', '07h 40m', '05:10', 2.3, '500', 45)
# Inserting row 5 for Tezpur to Tinsukia - Private
# ('ASTC-Assam State Transport', 'Tezpur to Tinsukia', 'Private', 'Aniruddha Travels', 'NON A/C Seater/ Sleeper (2+1)', '19:30', '09h 15m', '04:45', 3.0, '600', 17)
# Inserting row 6 for Tezpur to Tinsukia - Private
# ('ASTC-Assam State Transport', 'Tezpur to Tinsukia', 'Private', 'PIHU TRANSPORT', 'Bharat Benz NON A/C Seater / Sleeper (2+1)', '19:45', '09h 15m', '05:00', 3.0, '550', 32)
# Inserting row 7 for Tezpur to Tinsukia - Private
# ('ASTC-Assam State Transport', 'Tezpur to Tinsukia', 'Private', 'Puja Transport', 'NON AC Seater / Sleeper 2+1', '20:00', '09h 30m', '05:30', 2.3, '550', 30)
# Inserting row 8 for Tezpur to Tinsukia - Private
# ('ASTC-Assam State Transport', 'Tezpur to Tinsukia', 'Private', 'J.S. Travels', 'Non AC Seater (2+1)', '21:00', '09h 30m', '06:30', 2.1, '650', 35)
# Inserting data for operator type: Government on route: Tezpur to Tinsukia
# KeyError: 'Bus_Name' in route Tezpur to Tinsukia for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Dibrugarh to Bihpuria
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Dibrugarh to Bihpuria
# KeyError: 'Bus_Name' in route Dibrugarh to Bihpuria for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Dibrugarh to Bokakhat
# Minimum length of lists: 2
# Inserting row 1 for Dibrugarh to Bokakhat - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Bokakhat', 'Private', 'Assam State Transport Corporation (ASTC) - 139496', 'NON A/C Seater Push Back (2+1)', '09:30', '07h 00m', '16:30', 3.5, '273', 36)
# Inserting row 2 for Dibrugarh to Bokakhat - Private
# ('ASTC-Assam State Transport', 'Dibrugarh to Bokakhat', 'Private', 'SHIVAM TRAVELS', 'Bharat Benz A/C Seater (2+1)', '07:45', '04h 45m', '12:30', 4.7, '500', 42)
# Inserting data for operator type: Government on route: Dibrugarh to Bokakhat
# KeyError: 'Bus_Name' in route Dibrugarh to Bokakhat for operator type Government. Skipping...
# <mysql.connector.connection.MySQLConnection object at 0x000001F724330BF0>
# Inserting data for operator type: Private on route: Vijayawada to Hyderabad
# Minimum length of lists: 134
# Inserting row 1 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '23:25', '07h 00m', '06:25', 4.6, '396', 28)
# Inserting row 2 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:30', '06h 50m', '05:20', 4.6, '409', 20)
# Inserting row 3 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'GMRK Tours and Travels', 'Volvo A/C Semi Sleeper (2+2)', '23:45', '06h 10m', '05:55', 4.7, '406', 21)
# Inserting row 4 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'AdSri Sanvi Tours and Travels', 'A/C Sleeper (2+1)', '23:25', '05h 52m', '05:17', 4.7, '435', 22)
# Inserting row 5 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '23:45', '06h 15m', '06:00', 4.7, '344', 28)
# Inserting row 6 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '17:30', '06h 35m', '00:05', 4.6, '595', 29)
# Inserting row 7 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '16:20', '06h 55m', '23:15', 4.6, '630', 23)
# Inserting row 8 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'AdIntrCity SmartBus', 'VE A/C Seater / Sleeper (2+1)', '23:05', '06h 35m', '05:40', 4.7, '397', 21)
# Inserting row 9 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '23:50', '06h 20m', '06:10', 4.6, '675', 35)
# Inserting row 10 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '21:30', '06h 35m', '04:05', 4.5, '620', 27)
# Inserting row 11 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'FRESHBUS', 'Electric A/C Seater (2+2)', '23:25', '06h 30m', '05:55', 4.5, '553', 23)
# Inserting row 12 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Zingbus Plus', 'A/C Seater / Sleeper (2+1)', '22:50', '06h 50m', '05:40', 4.6, '450', 14)
# Inserting row 13 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '23:40', '06h 50m', '06:30', 4.5, '550', 14)
# Inserting row 14 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Sri Durga Malleswari Travels', 'A/C Sleeper (2+1)', '22:30', '07h 15m', '05:45', 4.5, '880', 8)
# Inserting row 15 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '21:50', '06h 15m', '04:05', 4.4, '620', 19)
# Inserting row 16 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'IntrCity SmartBus', 'A/C Sleeper (2+1)', '23:45', '06h 15m', '06:00', 4.7, '450', 22)
# Inserting row 17 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '23:00', '06h 45m', '05:45', 4.6, '667', 24)
# Inserting row 18 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '22:35', '06h 35m', '05:10', 4.3, '530', 17)
# Inserting row 19 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'IntrCity SmartBus', 'Scania AC Multi Axle Sleeper (2+1)', '23:20', '06h 35m', '05:55', 4.3, '555', 15)
# Inserting row 20 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Svkdt travels', 'A/C Sleeper (2+1)', '23:20', '06h 54m', '06:14', 4.3, '500', 16)
# Inserting row 21 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Sri KVR Travels', 'A/C Sleeper (2+1)', '23:45', '05h 50m', '05:35', 4.3, '449', 18)
# Inserting row 22 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Yolo Bus', 'A/C Seater / Sleeper (2+1)', '23:24', '06h 19m', '05:43', 4.2, '900', 11)
# Inserting row 23 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Sri Sai Srinivasa Travels', 'Non A/C Seater / Sleeper (2+1)', '22:00', '06h 57m', '04:57', 4.5, '600', 17)
# Inserting row 24 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'NueGo', 'Electric A/C Seater/Sleeper (2+1)', '23:00', '07h 30m', '06:30', 4.1, '500', 27)
# Inserting row 25 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '23:25', '07h 30m', '06:55', 4.1, '690', 13)
# Inserting row 26 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'BSR Tours And Travels', 'VE A/C Sleeper (2+1)', '23:50', '06h 25m', '06:15', 4.6, '600', 25)
# Inserting row 27 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '22:30', '07h 30m', '06:00', 4.0, '700', 17)
# Inserting row 28 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Svkdt travels', 'A/C Sleeper (2+1)', '23:00', '06h 50m', '05:50', 4.1, '500', 11)
# Inserting row 29 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Sri KVR Travels', 'Non A/C Seater / Sleeper (2+1)', '23:30', '06h 15m', '05:45', 4.2, '700', 15)
# Inserting row 30 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Sri Durga Malleswari Travels', 'A/C Sleeper (2+1)', '22:30', '07h 25m', '05:55', 4.1, '500', 11)
# Inserting row 31 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Svkdt travels', 'A/C Seater / Sleeper (2+1)', '22:45', '06h 55m', '05:40', 4.1, '490', 8)
# Inserting row 32 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'NueGo', 'Electric A/C Seater/Sleeper (2+1)', '21:30', '07h 50m', '05:20', 4.0, '630', 17)
# Inserting row 33 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '22:45', '07h 12m', '05:57', 4.1, '590', 20)
# Inserting row 34 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Sri KVR Travels', 'NON A/C Sleeper (2+1)', '23:20', '06h 05m', '05:25', 3.9, '400', 20)
# Inserting row 35 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Pavan Tours and Travels', 'A/C Sleeper (2+1)', '23:10', '06h 05m', '05:15', 4.5, '600', 27)
# Inserting row 36 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Tirumala Xpress', 'A/C Sleeper (2+1)', '23:20', '06h 50m', '06:10', 3.9, '700', 20)
# Inserting row 37 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'V Kaveri Travels', 'A/C Seater / Sleeper (2+1)', '23:05', '06h 45m', '05:50', 3.9, '499', 25)
# Inserting row 38 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Anjani Bus', 'A/C Seater / Sleeper (2+1)', '23:15', '06h 33m', '05:48', 3.8, '690', 25)
# Inserting row 39 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Royal Varma Travels', 'A/C Sleeper (2+1)', '22:28', '06h 49m', '05:17', 4.5, '700', 20)
# Inserting row 40 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'Orange Tours And Travels', 'NON A/C Sleeper (2+1)', '23:10', '06h 52m', '06:02', 3.8, '560', 32)
# Inserting row 41 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'NueGo', 'Electric A/C Seater (2+2)', '23:59', '07h 13m', '07:12', 3.7, '590', 31)
# Inserting row 42 for Vijayawada to Hyderabad - Private
# ('APSRTC-Andhra Pradesh State Transport', 'Vijayawada to Hyderabad', 'Private', 'J GAGANA TRAVELS', 'A/C Seater / Sleeper (2+1)', '00:30', '05h 00m', '05:30', 3.7, '600', 41)
# Inserting row 43 for Vijayawada to Hyderabad - Private
# ...
# Inserting row 17 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Goel Tourist (Regd)', 'A/C Seater / Sleeper (2+2)', '17:30', '13h 00m', '06:30', 3.9, '1099', 44)
# Inserting row 18 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Travel Point', 'A/C Seater / Sleeper (2+2)', '18:00', '13h 15m', '07:15', 3.7, '767', 36)
# Inserting row 19 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Ashok Bus Service', 'VE A/C Seater / Sleeper (2+1)', '18:45', '13h 30m', '08:15', 4.3, '599', 33)
# Inserting row 20 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'KVS Holidays', 'A/C Seater / Sleeper (2+2)', '17:00', '12h 30m', '05:30', 3.1, '899', 42)
# Inserting row 21 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'City Land Travels', 'A/C Seater/Sleeper (2+1)', '20:30', '13h 00m', '09:30', 3.7, '599', 31)
# Inserting row 22 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Lucky Bus Service', 'VE A/C Sleeper (2+2)', '19:30', '11h 50m', '07:20', 4.4, '893', 32)
# Inserting row 23 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Ashok Bus Service', 'A/C Seater / Sleeper (2+2)', '21:45', '12h 45m', '10:30', 3.0, '1199', 52)
# Inserting row 24 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Ashok Bus Service', 'A/C Seater / Sleeper (2+2)', '23:35', '13h 25m', '13:00', 1.8, '849', 47)
# Inserting row 25 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Travel Point World LLP', 'A/C Seater / Sleeper (2+2)', '18:30', '13h 20m', '07:50', 3.5, '699', 34)
# Inserting row 26 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Shub Yatra Holidays', 'A/C Sleeper (2+2)', '22:45', '12h 15m', '11:00', 2.5, '699', 30)
# Inserting row 27 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'DS Hari Travels', 'A/C Seater / Sleeper (2+2)', '21:00', '13h 00m', '10:00', 2.7, '900', 36)
# Inserting row 28 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'SHAH HOLIDAY TRAVEL', 'Bharat Benz A/C Seater / Sleeper (2+2)', '21:00', '13h 00m', '10:00', 2.6, '599', 35)
# Inserting row 29 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'City Land Travels', 'A/C Seater/Sleeper (2+1)', '23:00', '12h 20m', '11:20', 3.5, '1599', 30)
# Inserting row 30 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Travel Point', 'A/C Seater / Sleeper (2+2)', '21:30', '12h 45m', '10:15', 1.8, '799', 36)
# Inserting row 31 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Maheshwaram Travels', 'A/C Seater / Sleeper (2+2)', '19:00', '12h 35m', '07:35', 1.1, '875', 31)
# Inserting row 32 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'RK Holiday', 'A/C Seater / Sleeper (2+2)', '22:10', '12h 45m', '10:55', 3.5, '800', 37)
# Inserting row 33 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'City Land Travels', 'A/C Seater/Sleeper (2+1)', '18:00', '13h 30m', '07:30', 3.6, '599', 37)
# Inserting row 34 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'FlixBus', 'A/C Sleeper (2+1)', '18:30', '13h 35m', '08:05', 5.0, '1000', 8)
# Inserting row 35 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Big Bus', 'A/C Seater / Sleeper (2+2)', '20:30', '10h 30m', '07:00', 2.8, '1599', 39)
# Inserting row 36 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Red Apple Bus Service', 'A/C Seater / Sleeper (2+2)', '22:00', '10h 30m', '08:30', 2.0, '1449', 24)
# Inserting row 37 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Big Bus', 'A/C Seater / Sleeper (2+2)', '17:35', '12h 00m', '05:35', 2.7, '699', 39)
# Inserting row 38 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'FlixBus', 'A/C Sleeper (2+1)', '21:00', '13h 35m', '10:35', 3.8, '799', 9)
# Inserting row 39 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'NKS Holidays', 'A/C Sleeper (2+2)', '17:00', '13h 00m', '06:00', 3.8, '899', 28)
# Inserting row 40 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'BSS COOL COOL TRAVELS', 'A/C Seater / Sleeper (2+2)', '19:00', '12h 00m', '07:00', 4.5, '999', 24)
# Inserting row 41 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'NEW KING BUS SERVICE', 'A/C Seater / Sleeper (2+2)', '22:45', '11h 25m', '10:10', 2.8, '1800', 26)
# Inserting row 42 for Delhi to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Delhi to Jammu (j and k)', 'Private', 'Jamna Travels (Delhi)', 'A/C Seater / Sleeper (2+2)', '20:00', '13h 15m', '09:15', 2.5, '1800', 23)
# Inserting data for operator type: Government on route: Delhi to Jammu (j and k)
# KeyError: 'Bus_Name' in route Delhi to Jammu (j and k) for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Katra (jammu and kashmir) to Jammu (j and k)
# Minimum length of lists: 2
# Inserting row 1 for Katra (jammu and kashmir) to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Katra (jammu and kashmir) to Jammu (j and k)', 'Private', 'Vijay Tour and Travels', 'Bharat Benz A/C Seater /Sleeper (2+1)', '16:20', '01h 40m', '18:00', 3.5, '115', 32)
# Inserting row 2 for Katra (jammu and kashmir) to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Katra (jammu and kashmir) to Jammu (j and k)', 'Private', 'SPEED BUS', 'Bharat Benz A/C Seater /Sleeper (2+1)', '18:00', '01h 30m', '19:30', 3.7, '103', 34)
# Inserting data for operator type: Government on route: Katra (jammu and kashmir) to Jammu (j and k)
# KeyError: 'Bus_Name' in route Katra (jammu and kashmir) to Jammu (j and k) for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jammu (j and k) to Katra (jammu and kashmir)
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jammu (j and k) to Katra (jammu and kashmir)
# KeyError: 'Bus_Name' in route Jammu (j and k) to Katra (jammu and kashmir) for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Mendhar (J & K) to Jammu (j and k)
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Mendhar (J & K) to Jammu (j and k)
# KeyError: 'Bus_Name' in route Mendhar (J & K) to Jammu (j and k) for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jammu (j and k) to Poonch
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jammu (j and k) to Poonch
# KeyError: 'Bus_Name' in route Jammu (j and k) to Poonch for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Haridwar to Jammu (j and k)
# Minimum length of lists: 3
# Inserting row 1 for Haridwar to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Haridwar to Jammu (j and k)', 'Private', 'Laxmi holidays', 'Bharat Benz A/C Seater /Sleeper (2+1)', '17:30', '12h 30m', '06:00', 4.2, '640', 20)
# Inserting row 2 for Haridwar to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Haridwar to Jammu (j and k)', 'Private', 'SHRI KRISHNA TRAVELS (JAI SHREE GANESH YATRA CO.)', 'VE A/C Seater / Sleeper (2+1)', '18:20', '12h 40m', '07:00', 3.8, '800', 9)
# Inserting row 3 for Haridwar to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Haridwar to Jammu (j and k)', 'Private', 'City Land Travels', 'A/C Seater/Sleeper (2+1)', '20:00', '12h 00m', '08:00', 3.7, '1024', 11)
# Inserting data for operator type: Government on route: Haridwar to Jammu (j and k)
# KeyError: 'Bus_Name' in route Haridwar to Jammu (j and k) for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Chandigarh to Jammu (j and k)
# Minimum length of lists: 14
# Inserting row 1 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Laxmi holidays', 'Bharat Benz A/C Seater /Sleeper (2+1)', '22:50', '07h 10m', '06:00', 4.4, '640', 19)
# Inserting row 2 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Laxmi holidays', 'Bharat Benz A/C Sleeper (2+1)', '23:30', '07h 30m', '07:00', 4.6, '720', 15)
# Inserting row 3 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Laxmi holidays', 'Bharat Benz A/C Seater /Sleeper (2+1)', '23:05', '06h 55m', '06:00', 4.4, '494', 14)
# Inserting row 4 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'AdBaru travels', 'A/C Seater / Sleeper (2+2)', '20:45', '07h 30m', '04:15', 4.0, '900', 22)
# Inserting row 5 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Moon Light Travels Katra', 'A/C Sleeper (2+1)', '21:15', '07h 15m', '04:30', 4.4, '450', 2)
# Inserting row 6 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Laxmi holidays', 'Volvo 9600 Multi-Axle A/C Sleeper (2+1)', '23:50', '07h 10m', '07:00', 4.4, '570', 29)
# Inserting row 7 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Zimindara Travels', 'A/C Seater / Sleeper (2+1)', '22:30', '07h 00m', '05:30', 4.3, '599', 15)
# Inserting row 8 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'AdNew Pal Travels', 'A/C Sleeper (2+1)', '19:30', '10h 15m', '05:45', 3.9, '599', 12)
# Inserting row 9 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Harikesh Tour N Travels', 'A/C Sleeper (2+1)', '21:00', '07h 30m', '04:30', 4.0, '720', 8)
# Inserting row 10 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Jamna Travels-Jammu', 'AshokLeyland Stile A/C', '20:15', '08h 15m', '04:30', 3.9, '624', 21)
# Inserting row 11 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Zimindara Travels', 'AC Sleeper (2+1)', '21:30', '07h 00m', '04:30', 3.7, '699', 8)
# Inserting row 12 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Zimindara Travels', 'AC Sleeper (2+1)', '22:00', '07h 00m', '05:00', 3.6, '699', 5)
# Inserting row 13 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'SHRI KRISHNA TRAVELS (JAI SHREE GANESH YATRA CO.)', 'VE A/C Seater / Sleeper (2+1)', '23:30', '07h 30m', '07:00', 3.6, '899', 17)
# Inserting row 14 for Chandigarh to Jammu (j and k) - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Chandigarh to Jammu (j and k)', 'Private', 'Zimindara Travels', 'AC Sleeper (2+1)', '23:00', '07h 00m', '06:00', 4.0, '599', 25)
# Inserting data for operator type: Government on route: Chandigarh to Jammu (j and k)
# KeyError: 'Bus_Name' in route Chandigarh to Jammu (j and k) for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jammu (j and k) to Kishtwar
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jammu (j and k) to Kishtwar
# KeyError: 'Bus_Name' in route Jammu (j and k) to Kishtwar for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jammu (j and k) to Mendhar (J & K)
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Jammu (j and k) to Mendhar (J & K)
# KeyError: 'Bus_Name' in route Jammu (j and k) to Mendhar (J & K) for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Jammu (j and k) to Amritsar
# Minimum length of lists: 4
# Inserting row 1 for Jammu (j and k) to Amritsar - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Jammu (j and k) to Amritsar', 'Private', 'Bhawani Travels', 'Bharat Benz A/C Seater (2+2)', '16:30', '04h 35m', '21:05', 3.2, '399', 28)
# Inserting row 2 for Jammu (j and k) to Amritsar - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Jammu (j and k) to Amritsar', 'Private', 'Jamna Travels-Jammu', 'A/C Seater Push Back (2+2)', '16:30', '04h 15m', '20:45', 3.2, '399', 30)
# Inserting row 3 for Jammu (j and k) to Amritsar - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Jammu (j and k) to Amritsar', 'Private', 'Bhawani Travels', 'Bharat Benz A/C Seater (2+2)', '18:30', '04h 45m', '23:15', 3.7, '399', 40)
# Inserting row 4 for Jammu (j and k) to Amritsar - Private
# ('JKSRTC-Jammu and Kashmir State Road Transport Corporation', 'Jammu (j and k) to Amritsar', 'Private', 'Jamna Travels-Jammu', 'A/C Seater / Sleeper (2+2)', '22:30', '05h 15m', '03:45', 3.6, '279', 52)
# Inserting data for operator type: Government on route: Jammu (j and k) to Amritsar
# KeyError: 'Bus_Name' in route Jammu (j and k) to Amritsar for operator type Government. Skipping...
# Inserting data for operator type: Private on route: Ajmer to Jammu (j and k)
# Minimum length of lists: 0
# Inserting data for operator type: Government on route: Ajmer to Jammu (j and k)
# KeyError: 'Bus_Name' in route Ajmer to Jammu (j and k) for operator type Government. Skipping...
